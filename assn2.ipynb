# %% [markdown]
# # HW02
# In this assignment, you will learn how to preprocess data using SQLite and Pandas.
#
# Please follow the instructions below:
#
# 1. Write down your code between <br>
# &nbsp;&nbsp;&nbsp;&nbsp; **\# BEGIN_YOUR_CODE**<br>
# &nbsp;&nbsp;&nbsp;&nbsp; and<br>
# &nbsp;&nbsp;&nbsp;&nbsp; **\# END_YOUR_CODE**.
#
# 2. Do not use **external libraries**. (i.e., Do not use any `import` in your code) <br>
#    Your code will fail to execute and get **0 score** if you use them.
#
# 3. Rename this file to **[student_id].ipynb** (e.g. 20221234.ipynb) and submit it to PLMS. <br>
#    There is **20% penalty** if you do not follow the submission format.
#
# 4. Submission more than one day late is not accepted.
#    There is **50% penalty** for late submission up to one day.

# %%
import sqlite3
import pandas as pd

from typing import List, Tuple

# %% [markdown]
# ## Problem 1. SQLite and Python [8 points]

# %% [markdown]
# ### a. Create [1 points]
# Implement function `create` that connects a database named `titanic.db` and creates a table named `Company` in it. <br>
# The contents of table `Company` are as follow:
#    | Employee | Department | Salary | Gender |
#    | :-       | :-         | :-     | :-     |
#    | John     | sales      | 5000   | M      |
#    | Allen    | accounting | 6000   | M      |
#    | Martin   | research   | 3500   | M      |
#    | Mary     | sales      | 5500   | F      |
#    | Smith    | research   | 4500   | M      |

# %%
def create() -> None:
    '''
        create() connects a database named |titanic.db| and creates a table |Company| in it.

        Columns and data types of table |Company| are as follow:
            |Employee|   - string
            |Department| - string
            |Salary|     - int
            |Gender|     - string
        
        The order of data insertion does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect("titanic.db")
    cursor = conn.cursor()

    cursor.execute("CREATE TABLE IF NOT EXISTS Company (Employee TEXT, Department TEXT, Salary INTEGER, Gender TEXT)")

    content = [
        ('John', 'sales', 5000, 'M'), 
        ('Allen', 'accounting', 6000, 'M'), 
        ('Martin', 'research', 3500, 'M'), 
        ('Mary', 'sales', 5500, 'F'), 
        ('Smith', 'research', 4500, 'M'), 
    ]

    cursor.executemany('INSERT INTO Company VALUES(?, ?, ?, ?)', content) 
    

    conn.commit()
    conn.close() 

    # END_YOUR_CODE

#create()

# %% [markdown]
# ### b. Select 1 [1 points]
# Implement function `select1` that fetches all data from table `Titanic` in database `titanic.db`.

# %%
def select1() -> List[Tuple[int, str, int, int]]:
    '''
        select1() fetches all data from table |Titatic| in database |titanic.db|
            and returns them as a list of tuples.

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Pclass|, |Name|, |Survived|, |Age| )
            for 1 <= n <= N.

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect("titanic.db")
    cursor = conn.cursor()

    cursor.execute("SELECT Pclass, Name, Survived, Age FROM Titanic")

    data = cursor.fetchall()

    conn.close()

    return data 
    # raise Exception('Not implemented yet')
    # END_YOUR_CODE

#result = select1() 
#for row in result: 
#    print (row)

# %% [markdown]
# ### c. Select 2 [2 points]
# Implement function `select2` that fetches all data of survivals under the age of 65 from table `Titanic` in database `titanic.db`. <br>
# The data shoulbe be arranged in ascending order of age.

# %%
def select2() -> List[Tuple[int, str, int, int]]:
    '''
        select2() fetches all data satisfying certain condition from table |Titatic| in database |titanic.db|
            and returns them as a list of tuples.

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Pclass|, |Name|, |Survived|, |Age| ), |Survived| == 1, |Age| < 65
            for 1 <= n <= N.

        The tuples should be arranged in ascending order of |Age|.
        The order of tuples with the same |Age| does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')
    cursor = conn.cursor()

    cursor.execute("SELECT Pclass, Name, Survived, Age FROM Titanic WHERE Survived = 1 AND Age < 65 ORDER BY Age")

    data = cursor.fetchall() 

    conn.close()

    return data 

    # END_YOUR_CODE

#result = select2() 
#for row in result: 
#    print (row)

# %% [markdown]
# ### d. Select 3 [2 points]
# Implement function `select3` that fetches all data from table `Titanic` in database `titanic.db` <br>
# and calculates average age of passengers by ticket class.

# %%
def select3() -> List[Tuple[int, float]]:
    '''
        select3() fetches all data from table |Titatic| in database |titanic.db|,
            calculates average age by |Pclass|, and returns them as a list of tuples.

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Pclass|, average |Age| )
            for 1 <= n <= N.

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect ('titanic.db')
    cursor = conn.cursor() 

    cursor.execute("SELECT Pclass, AVG(Age) FROM Titanic GROUP BY Pclass")

    avg_age = cursor.fetchall() 

    conn.close() 

    return avg_age
    # END_YOUR_CODE

#result = select3() 
#for item in result: 
#    print (f"Pclass: {item[0]}, Average Age: {item[1]}")
# Out:
# Pclass: 1, Average Age: 39.06944444444444
# Pclass: 2, Average Age: 30.891472868217054
# Pclass: 3, Average Age: 26.484732824427482

# %% [markdown]
# ### e. Join [2 points]
# Implement function `join` that left-joins two tables `Company` and `Titanic` in database `titanic.db` by name. <br>
# In this problem, table `Company` is utilized, which means you should successfully implement function `create` to start this problem.

# %%
def join() -> List[Tuple[str, str, int, str, int, str, int, int]]:
    '''
        join() left-joins two tables |Company| and |Titatic| in database |titanic.db|
            and returns them as a list of tuples.
        
        Columns and data types of table |Company| are as follow:
            |Employee|   - string
            |Department| - string
            |Salary|     - int
            |Gender|     - string

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Employee|, |Department|, |Salary|, |Gender|, |Pclass|, |Name|, |Survived|, |Age| )
            for 1 <= n <= N.    

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')
    cursor = conn.cursor() 

    cursor.execute("""
        SELECT C.Employee, C. Department, C.Salary, C.Gender, T.Pclass, T.Name, T.Survived, T.Age
        FROM Company C
        LEFT JOIN Titanic T ON C.Employee = T.Name
    """)

    data = cursor.fetchall() 

    conn.close() 

    return data
    # END_YOUR_CODE

#result = join() 
#for item in result:
#    print(item)
# Out:
# ('John', 'sales', 5000, 'M', None, None, None, None)
# ('Allen', 'accounting', 6000, 'M', 3, 'Allen', 0, 35)
# ('Martin', 'research', 3500, 'M', None, None, None, None)
# ('Mary', 'sales', 5500, 'F', None, None, None, None)
# ('Smith', 'research', 4500, 'M', 1, 'Smith', 0, 56)
# ('John', 'sales', 5000, 'M', None, None, None, None)
# ('Allen', 'accounting', 6000, 'M', 3, 'Allen', 0, 35)
# ('Martin', 'research', 3500, 'M', None, None, None, None)
# ('Mary', 'sales', 5500, 'F', None, None, None, None)
# ('Smith', 'research', 4500, 'M', 1, 'Smith', 0, 56)

# %% [markdown]
# ## Problem 2. SQLite and Pandas [4 points]

# %% [markdown]
# ### a. from SQLite Database to Pandas Dataframe [2 points]
# Implement function `db2df` that converts table `Titanic` in database `titanic.db` into pandas dataframe and saves it in `titanic.csv`.

# %%
def db2df() -> None:
    '''
        db2df() converts table |Titanic| in database |titanic.db| into pandas dataframe
            and saves it in |titanic.csv|.

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        Columns of the converted dataframe, namely df, should be as follow:
            df.columns == ['Pclass', 'Name', 'Survived', 'Age']

        The order of rows does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')

    query = 'SELECT *FROM Titanic'
    df = pd.read_sql_query(query, conn)

    conn.close() 

    df = df[['Pclass', 'Name', 'Survived', 'Age']]

    df.to_csv ('titanic.csv', index = False)
    #print(df)
    # END_YOUR_CODE

#db2df()
# Out:
#      Pclass       Name  Survived  Age
# 0         3     Braund         0   22
# 1         1    Cumings         1   38
# 2         3  Heikkinen         1   26
# 3         1   Futrelle         1   35
# 4         3      Allen         0   35
# ..      ...        ...       ...  ...
# 530       2   Banfield         0   28
# 531       3   Sutehall         0   25
# 532       2   Montvila         0   27
# 533       1       Behr         1   26
# 534       3     Dooley         0   32
#
# [535 rows x 4 columns]

# %% [markdown]
# ### b. from Pandas Dataframe to SQLite Database [2 points]
# Implement function `df2db` that converts pandas dataframe read from `titanic2.csv` into table `Titanic2` and saves it in database `titanic.db`.

# %%
def df2db() -> None:
    '''
        df2db() converts pandas dataframe read from |titanic2.csv| into table |Titanic2|
            and saves it in |titanic.db|.

        Columns and data types of table |Titanic2| are as follow:
            |Ticket| - string
            |Fare|   - int
        
        The order of columns and data in table |Titanic2| does not matter.
    '''
    # BEGIN_YOUR_CODE
    df = pd.read_csv('titanic2.csv')
    
    conn = sqlite3.connect('titanic.db')
    
    df.to_sql('Titanic2', conn, if_exists = 'replace', index = False) 

    conn.commit() 
    conn.close() 

    #print(df)

    # END_YOUR_CODE

#df2db()
# Out:
#                Ticket  Fare
# 0           A/5 21171     7
# 1            PC 17599    71
# 2    STON/O2. 3101282     7
# 3              113803    53
# 4              373450     8
# ..                ...   ...
# 530  C.A./SOTON 34068    10
# 531   SOTON/OQ 392076     7
# 532            211536    13
# 533            111369    30
# 534            370376     7
#
# [535 rows x 2 columns]

# %% [markdown]
# ## Problem 3. Relational Algebra [8 points]
# Connect to database `titanic.db`, execute following relational algebra expression, and return fetched data. <br>
# In this problem, tables `Company` and `Titanic2` are utilized, which means you should successfully implement functions `create` and `df2db` to start this problem.

# %% [markdown]
# ### a. [2 points]
# $\pi_{Ticket, Fare}(\sigma_{Fare > 30}(Titanic2))$

# %%
def rel_alg1() -> List[Tuple[str, int]]:
    '''
        rel_alg1() connects to database |titanic.db|, executes given relational algebra expression,
            and returns fetched data as a list of tuples.
        
        Columns and data types of table |Company| are as follow:
            |Employee|   - string
            |Department| - string
            |Salary|     - int
            |Gender|     - string

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int

        Columns and data types of table |Titanic2| are as follow:
            |Ticket| - string
            |Fare|   - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Ticket|, |Fare| )
            for 1 <= n <= N.    

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')

    query = """
        SELECT Ticket, Fare
        FROM Titanic2
        WHERE Fare > 30 
    """

    cursor = conn.cursor() 
    cursor.execute(query)

    data = cursor.fetchall() 

    conn.close() 

    return data 
    # END_YOUR_CODE

#result = rel_alg1() 
#for row in result:
#    print(row)
# Out:
# ('PC 17599', 71)
# ('113803', 53)
# ('17463', 51)
# ('347082', 31)
# ('113788', 35)
# ('347077', 31)
# ('19950', 263)
# ('PC 17604', 82)
# ('113789', 52)
# ('SC/Paris 2123', 41)
# ('3101295', 39)
# ('PC 17572', 76)
# ('113509', 61)
# ('CA 2144', 46)
# ('113572', 80)
# ('36973', 83)
# ('S.O.C. 14879', 73)
# ('1601', 56)
# ('113059', 47)
# ('W./C. 6608', 34)
# ('W.E.P. 5734', 61)
# ('PC 17754', 34)
# ('PC 17759', 63)
# ('35281', 77)
# ('110465', 52)
# ('PC 17558', 247)
# ('S.O.C. 14879', 73)
# ('PC 17593', 79)
# ('C.A. 33112', 36)
# ('113776', 66)
# ('PC 17597', 61)
# ('1601', 56)
# ('111240', 33)
# ('230136', 39)
# ('PC 17569', 146)
# ('112277', 31)
# ('35273', 113)
# ('11813', 76)
# ('19943', 90)
# ('19928', 90)
# ('11751', 52)
# ('110152', 86)
# ('PC 17755', 512)
# ('110413', 79)
# ('PC 17582', 153)
# ('PC 17760', 135)
# ('13502', 77)
# ('19877', 78)
# ('11967', 91)
# ('113781', 151)
# ('PC 17758', 108)
# ('PC 17485', 56)
# ('11767', 83)
# ('PC 17608', 262)
# ('36928', 164)
# ('16966', 134)
# ('PC 17760', 135)
# ('111361', 57)
# ('16966', 134)
# ('113784', 35)
# ('113505', 55)
# ('110813', 75)
# ('PC 17477', 69)
# ('11765', 55)
# ('PC 17760', 135)
# ('113503', 211)
# ('PC 17757', 227)
# ('S.O.C. 14879', 73)
# ('28220', 32)
# ('13507', 55)
# ('33638', 81)
# ('17453', 89)
# ('111320', 38)
# ('PC 17609', 49)
# ('36947', 78)
# ('110152', 86)
# ('1601', 56)
# ('PC 17603', 59)
# ('36967', 34)
# ('12749', 93)
# ('PC 17761', 106)
# ('13568', 49)
# ('WE/P 5735', 71)
# ('PC 17761', 106)
# ('17421', 110)
# ('11755', 39)
# ('11769', 51)
# ('13049', 40)
# ('13567', 79)
# ('36947', 78)
# ('PC 17582', 153)
# ('220845', 65)
# ('11753', 52)
# ('36963', 32)
# ('13502', 77)
# ('PC 17477', 69)
# ('13213', 35)
# ('PC 17611', 133)
# ('F.C. 12750', 52)
# ('PC 17755', 512)
# ('PC 17572', 76)
# ('24160', 211)
# ('17474', 57)
# ('PC 17757', 227)
# ('113781', 151)
# ('PC 17482', 49)
# ('19996', 52)
# ('PC 17757', 227)
# ('113806', 53)
# ('PC 17755', 512)
# ('19877', 78)
# ('113773', 53)
# ('110152', 86)
# ('13502', 77)
# ('24160', 211)
# ('PC 17593', 79)
# ('S.C./PARIS 2079', 37)
# ('113572', 80)
# ('PC 17756', 83)
# ('1601', 56)
# ('113798', 31)
# ('PC 17592', 39)
# ('PC 17590', 50)
# ('11767', 83)

# %% [markdown]
# ### b. [3 points]
# $\pi_{Name, Survived}(\sigma_{Pclass = 2}(Titanic)) - \pi_{Name, Survived}(\sigma_{Age \ge 20}(Titanic))$

# %%
def rel_alg2() -> List[Tuple[str, int]]:
    '''
        rel_alg2() connects to database |titanic.db|, executes given relational algebra expression,
            and returns fetched data as a list of tuples.
        
        Columns and data types of table |Company| are as follow:
            |Employee|   - string
            |Department| - string
            |Salary|     - int
            |Gender|     - string

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int

        Columns and data types of table |Titanic2| are as follow:
            |Ticket| - string
            |Fare|   - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Name|, |Survived| )
            for 1 <= n <= N. 

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')

    query = """ 
        SELECT Name, Survived
        FROM Titanic 
        WHERE Pclass = 2
        EXCEPT 
        SELECT Name, Survived 
        FROM Titanic 
        WHERE Age >= 20
    """

    cursor = conn.cursor() 
    cursor.execute(query)

    data = cursor.fetchall() 

    conn.close() 

    return data 
    # END_YOUR_CODE

#result = rel_alg2() 
#for row in result:
#    print(row)

# %% [markdown]
# ### c. [3 points]
# $\pi_{Employee, Salary, Age}(\sigma_{Employee = Name}(Company \times Titanic))$

# %%
def rel_alg3() -> List[Tuple[str, int, int]]:
    '''
        rel_alg3() connects to database |titanic.db|, executes given relational algebra expression,
            and returns fetched data as a list of tuples.
        
        Columns and data types of table |Company| are as follow:
            |Employee|   - string
            |Department| - string
            |Salary|     - int
            |Gender|     - string

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int

        Columns and data types of table |Titanic2| are as follow:
            |Ticket| - string
            |Fare|   - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Employee|, |Salary|, |Age| )
            for 1 <= n <= N. 

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')

    query = """ 
        SELECT Company.Employee, Company.Salary, Titanic.Age
        FROM Company 
        JOIN Titanic ON Company.Employee = Titanic.Name
    """

    cursor = conn.cursor() 
    cursor.execute(query)

    data = cursor.fetchall() 

    conn.close() 

    return data  
    # END_YOUR_CODE

#result = rel_alg3() 
#for row in result:
#    print(row)
# Out:
# ('Allen', 6000, 35)
# ('Smith', 4500, 56)
# ('Allen', 6000, 35)
# ('Smith', 4500, 56)

# %% [markdown]
# ## Problem 4. Complicated SQL Query [10 points]
# In this problem, do not just fetch all data from table and use basic python operations to solve the problem. <br>
# Only SQL query is allowed.

# %% [markdown]
# ### a. Complicated Select 1 [3 ponts]
# Implement `comp_select1` that counts the number of passengers for each ticket class using table `Titanic` in database `titanic.db`.

# %%
def comp_select1() -> List[Tuple[int, int]]:
    '''
        comp_select1() counts the numbers of passengers for each ticket class using table |Titanic| in database |titanic.db|
            and returns them as a list of tuples.

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Pclass|, # of passengers )
            for 1 <= n <= N. 

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')

    query = """ 
        SELECT Pclass, COUNT(*) as PassengerCount
        FROM Titanic 
        GROUP BY Pclass 
    """

    cursor = conn.cursor() 
    cursor.execute(query)

    data = []
    row = cursor.fetchone() 

    if row is None:
        return data
    
    while row is not None:
        data.append(row)
        row = cursor.fetchone() 

    conn.close() 

    return data  
    # END_YOUR_CODE

#result = comp_select1() 
#for row in result:
#    print(row)
# Out:
# (1, 144)
# (2, 129)
# (3, 262)

# %% [markdown]
# ### b. Complicated Select 2 [3 ponts]
# Implement `comp_select2` that calculates the average age of passengers for each ticket class using table `Titanic` in database `titanic.db` <br>
# and finds ticket classes whose average passenger age is under 35.

# %%
def comp_select2() -> List[Tuple[int, int]]:
    '''
        comp_select2() calculates the average passenger age for each ticket class using table |Titanic| in database |titanic.db|,
            finds ticket classes whose average passenger age is under 35,
            and returns them as a list of tuples.

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Pclass|, average passenger age ), average passenger age < 35
            for 1 <= n <= N. 

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')

    query = """ 
        SELECT Pclass, AVG(Age) as AverageAge
        FROM Titanic 
        GROUP BY Pclass 
        HAVING AverageAge < 35
    """

    cursor = conn.cursor() 
    cursor.execute(query)

    data = []
    row = cursor.fetchone() 

    if row is None:
        return data
    
    while row is not None:
        data.append(row)
        row = cursor.fetchone() 

    conn.close() 

    return data 
    # END_YOUR_CODE

#result = comp_select2() 
#for row in result:
#    print(row)
# Out:
# (2, 30.891472868217054)
# (3, 26.484732824427482)

# %% [markdown]
# ### c. Complicated Select 3 [4 ponts]
# Implement `comp_select3` that finds every pair of survived passengers using table `Titanic` in database `titanic.db`. <br>
# For example, if `A`, `B`, `C` and `D` are all survived passengers, `comp_select3` would return `[(A, B), (A, C), (A, D), (B, C), (B, D), (C, D)]`. <br>
# The order of tuples in list can be changed.

# %%
def comp_select3() -> List[Tuple[str, str]]:
    '''
        comp_select3() finds every pair of survived passengers' names using table |Titanic| in database |titanic.db|
            and returns them as a list of tuples.

        Columns and data types of table |Titanic| are as follow:
            |Pclass|   - int
            |Name|     - string
            |Survived| - int
            |Age|      - int
        
        The returned list should be formatted as follow:
            [ Tuple_1, ..., Tuple_N ]
            where N is # of fetched data and
            Tuple_n = ( |Name|_1, |Name|_2 ), |Name|_1 and |Name|_2 are lexicographically ordered
            for 1 <= n <= N. 

        The order of tuples does not matter.
    '''
    # BEGIN_YOUR_CODE
    conn = sqlite3.connect('titanic.db')

    query = """ 
        SELECT a.Name, b.Name
        FROM Titanic a
        JOIN Titanic b ON a.Survived = 1 AND b.Survived = 1 AND a.Name < b.Name
    """

    cursor = conn.cursor() 
    cursor.execute(query)

    data = []
    row = cursor.fetchone() 
    if row is None:
        return data

    while row is not None:
        data.append(row)
        row = cursor.fetchone() 

    conn.close() 

    return data
    # END_YOUR_CODE

result = comp_select3() 
for row in result:
    print(row)
# Out:
# ('Cumings', 'Dahl')
# ('Cumings', 'Daly')
# ('Cumings', 'Daniel')
# ('Cumings', 'Davis')
# ('Cumings', 'Devaney')
# ('Cumings', 'Dick')
# ('Cumings', 'Dodge')
# ('Cumings', 'Doling')
# ('Cumings', 'Dorking')
# ('Cumings', 'Dowdell')
# ('Cumings', 'Drew')
# ('Cumings', 'Duff Gordon')
# ('Cumings', 'Duran y More')
# ('Cumings', 'Emanuel')
# ('Cumings', 'Endres')
# ('Cumings', 'Eustis')
# ('Cumings', 'Faunthorpe')
# ('Cumings', 'Flynn')
# ('Cumings', 'Francatelli')
# ('Cumings', 'Frauenthal')
# ('Cumings', 'Frolicher')
# ('Cumings', 'Frolicher-Stehli')
# ('Cumings', 'Futrelle')
# ('Cumings', 'Garside')
# ('Cumings', 'Gilnagh')
# ('Cumings', 'Goldenberg')
# ('Cumings', 'Goldsmith')
# ('Cumings', 'Graham')
# ('Cumings', 'Greenfield')
# ('Cumings', 'Hakkarainen')
# ('Cumings', 'Hamalainen')
# ('Cumings', 'Harder')
# ('Cumings', 'Harper')
# ('Cumings', 'Hassab')
# ('Cumings', 'Hays')
# ('Cumings', 'Hedman')
# ('Cumings', 'Heikkinen')
# ('Cumings', 'Herman')
# ('Cumings', 'Hewlett')
# ('Cumings', 'Hippach')
# ('Cumings', 'Hirvonen')
# ('Cumings', 'Hogeboom')
# ('Cumings', 'Homer')
# ('Cumings', 'Honkanen')
# ('Cumings', 'Hosono')
# ('Cumings', 'Hoyt')
# ('Cumings', 'Icard')
# ('Cumings', 'Ilett')
# ('Cumings', 'Jalsevac')
# ('Cumings', 'Jansson')
# ('Cumings', 'Jerwan')
# ('Cumings', 'Johnson')
# ('Cumings', 'Jonsson')
# ('Cumings', 'Karun')
# ('Cumings', 'Kimball')
# ('Cumings', 'Kink-Heilmann')
# ('Cumings', 'Landergren')
# ('Cumings', 'Lang')
# ('Cumings', 'Laroche')
# ('Cumings', 'LeRoy')
# ('Cumings', 'Leader')
# ('Cumings', 'Leeni')
# ('Cumings', 'Lehmann')
# ('Cumings', 'Lemore')
# ('Cumings', 'Lesurer')
# ('Cumings', 'Lindqvist')
# ('Cumings', 'Lines')
# ('Cumings', 'Longley')
# ('Cumings', 'Louch')
# ('Cumings', 'Lulic')
# ('Cumings', 'Lurette')
# ('Cumings', 'Madill')
# ('Cumings', 'Madsen')
# ('Cumings', 'Maioni')
# ('Cumings', 'Mayne')
# ('Cumings', 'McGough')
# ('Cumings', 'McGowan')
# ('Cumings', 'Mellinger')
# ('Cumings', 'Mellors')
# ('Cumings', 'Moor')
# ('Cumings', 'Najib')
# ('Cumings', 'Nakid')
# ('Cumings', 'Nasser')
# ('Cumings', 'Newell')
# ('Cumings', 'Newsom')
# ('Cumings', 'Nicola-Yarred')
# ('Cumings', 'Nilsson')
# ('Cumings', 'Niskanen')
# ('Cumings', 'Nye')
# ('Cumings', 'Nysten')
# ('Cumings', 'Ohman')
# ('Cumings', 'Osman')
# ('Cumings', 'Parrish')
# ('Cumings', 'Pears')
# ('Cumings', 'Penasco y Castellana')
# ('Cumings', 'Perreault')
# ('Cumings', 'Persson')
# ('Cumings', 'Peuchen')
# ('Cumings', 'Phillips')
# ('Cumings', 'Pickard')
# ('Cumings', 'Pinsky')
# ('Cumings', 'Potter')
# ('Cumings', 'Quick')
# ('Cumings', 'Reynaldo')
# ('Cumings', 'Richards')
# ('Cumings', 'Ridsdale')
# ('Cumings', 'Robert')
# ('Cumings', 'Romaine')
# ('Cumings', 'Rothes')
# ('Cumings', 'Rothschild')
# ('Cumings', 'Rugg')
# ('Cumings', 'Ryerson')
# ('Cumings', 'Sagesser')
# ('Cumings', 'Salkjelsvik')
# ('Cumings', 'Sandstrom')
# ('Cumings', 'Serepeca')
# ('Cumings', 'Seward')
# ('Cumings', 'Sheerlinck')
# ('Cumings', 'Shelley')
# ('Cumings', 'Shutes')
# ('Cumings', 'Silven')
# ('Cumings', 'Silverthorne')
# ('Cumings', 'Simonius-Blumer')
# ('Cumings', 'Sinkkonen')
# ('Cumings', 'Sjoblom')
# ('Cumings', 'Slayter')
# ('Cumings', 'Sloper')
# ('Cumings', 'Spedden')
# ('Cumings', 'Stahelin-Maeglin')
# ('Cumings', 'Stephenson')
# ('Cumings', 'Stone')
# ('Cumings', 'Stranden')
# ('Cumings', 'Sunderland')
# ('Cumings', 'Sundman')
# ('Cumings', 'Swift')
# ('Cumings', 'Taylor')
# ('Cumings', 'Thayer')
# ('Cumings', 'Thomas')
# ('Cumings', 'Toomey')
# ('Cumings', 'Tornquist')
# ('Cumings', 'Touma')
# ('Cumings', 'Trout')
# ('Cumings', 'Troutt')
# ('Cumings', 'Turja')
# ('Cumings', 'Turkula')
# ('Cumings', 'Ward')
# ('Cumings', 'Warren')
# ('Cumings', 'Watt')
# ('Cumings', 'Webber')
# ('Cumings', 'Weisz')
# ('Cumings', 'Wells')
# ('Cumings', 'West')
# ('Cumings', 'Wick')
# ('Cumings', 'Wilhelms')
# ('Cumings', 'Young')
# ('Cumings', 'de Messemaeker')
# ('Cumings', 'de Mulder')
# ('Heikkinen', 'Herman')
# ('Heikkinen', 'Hewlett')
# ('Heikkinen', 'Hippach')
# ('Heikkinen', 'Hirvonen')
# ('Heikkinen', 'Hogeboom')
# ('Heikkinen', 'Homer')
# ('Heikkinen', 'Honkanen')
# ('Heikkinen', 'Hosono')
# ('Heikkinen', 'Hoyt')
# ('Heikkinen', 'Icard')
# ('Heikkinen', 'Ilett')
# ('Heikkinen', 'Jalsevac')
# ('Heikkinen', 'Jansson')
# ('Heikkinen', 'Jerwan')
# ('Heikkinen', 'Johnson')
# ('Heikkinen', 'Jonsson')
# ('Heikkinen', 'Karun')
# ('Heikkinen', 'Kimball')
# ('Heikkinen', 'Kink-Heilmann')
# ('Heikkinen', 'Landergren')
# ('Heikkinen', 'Lang')
# ('Heikkinen', 'Laroche')
# ('Heikkinen', 'LeRoy')
# ('Heikkinen', 'Leader')
# ('Heikkinen', 'Leeni')
# ('Heikkinen', 'Lehmann')
# ('Heikkinen', 'Lemore')
# ('Heikkinen', 'Lesurer')
# ('Heikkinen', 'Lindqvist')
# ('Heikkinen', 'Lines')
# ('Heikkinen', 'Longley')
# ('Heikkinen', 'Louch')
# ('Heikkinen', 'Lulic')
# ('Heikkinen', 'Lurette')
# ('Heikkinen', 'Madill')
# ('Heikkinen', 'Madsen')
# ('Heikkinen', 'Maioni')
# ('Heikkinen', 'Mayne')
# ('Heikkinen', 'McGough')
# ('Heikkinen', 'McGowan')
# ('Heikkinen', 'Mellinger')
# ('Heikkinen', 'Mellors')
# ('Heikkinen', 'Moor')
# ('Heikkinen', 'Najib')
# ('Heikkinen', 'Nakid')
# ('Heikkinen', 'Nasser')
# ('Heikkinen', 'Newell')
# ('Heikkinen', 'Newsom')
# ('Heikkinen', 'Nicola-Yarred')
# ('Heikkinen', 'Nilsson')
# ('Heikkinen', 'Niskanen')
# ('Heikkinen', 'Nye')
# ('Heikkinen', 'Nysten')
# ('Heikkinen', 'Ohman')
# ('Heikkinen', 'Osman')
# ('Heikkinen', 'Parrish')
# ('Heikkinen', 'Pears')
# ('Heikkinen', 'Penasco y Castellana')
# ('Heikkinen', 'Perreault')
# ('Heikkinen', 'Persson')
# ('Heikkinen', 'Peuchen')
# ('Heikkinen', 'Phillips')
# ('Heikkinen', 'Pickard')
# ('Heikkinen', 'Pinsky')
# ('Heikkinen', 'Potter')
# ('Heikkinen', 'Quick')
# ('Heikkinen', 'Reynaldo')
# ('Heikkinen', 'Richards')
# ('Heikkinen', 'Ridsdale')
# ('Heikkinen', 'Robert')
# ('Heikkinen', 'Romaine')
# ('Heikkinen', 'Rothes')
# ('Heikkinen', 'Rothschild')
# ('Heikkinen', 'Rugg')
# ('Heikkinen', 'Ryerson')
# ('Heikkinen', 'Sagesser')
# ('Heikkinen', 'Salkjelsvik')
# ('Heikkinen', 'Sandstrom')
# ('Heikkinen', 'Serepeca')
# ('Heikkinen', 'Seward')
# ('Heikkinen', 'Sheerlinck')
# ('Heikkinen', 'Shelley')
# ('Heikkinen', 'Shutes')
# ('Heikkinen', 'Silven')
# ('Heikkinen', 'Silverthorne')
# ('Heikkinen', 'Simonius-Blumer')
# ('Heikkinen', 'Sinkkonen')
# ('Heikkinen', 'Sjoblom')
# ('Heikkinen', 'Slayter')
# ('Heikkinen', 'Sloper')
# ('Heikkinen', 'Spedden')
# ('Heikkinen', 'Stahelin-Maeglin')
# ('Heikkinen', 'Stephenson')
# ('Heikkinen', 'Stone')
# ('Heikkinen', 'Stranden')
# ('Heikkinen', 'Sunderland')
# ('Heikkinen', 'Sundman')
# ('Heikkinen', 'Swift')
# ('Heikkinen', 'Taylor')
# ('Heikkinen', 'Thayer')
# ('Heikkinen', 'Thomas')
# ('Heikkinen', 'Toomey')
# ('Heikkinen', 'Tornquist')
# ('Heikkinen', 'Touma')
# ('Heikkinen', 'Trout')
# ('Heikkinen', 'Troutt')
# ('Heikkinen', 'Turja')
# ('Heikkinen', 'Turkula')
# ('Heikkinen', 'Ward')
# ('Heikkinen', 'Warren')
# ('Heikkinen', 'Watt')
# ('Heikkinen', 'Webber')
# ('Heikkinen', 'Weisz')
# ('Heikkinen', 'Wells')
# ('Heikkinen', 'West')
# ('Heikkinen', 'Wick')
# ('Heikkinen', 'Wilhelms')
# ('Heikkinen', 'Young')
# ('Heikkinen', 'de Messemaeker')
# ('Heikkinen', 'de Mulder')
# ('Futrelle', 'Garside')
# ('Futrelle', 'Gilnagh')
# ('Futrelle', 'Goldenberg')
# ('Futrelle', 'Goldsmith')
# ('Futrelle', 'Graham')
# ('Futrelle', 'Greenfield')
# ('Futrelle', 'Hakkarainen')
# ('Futrelle', 'Hamalainen')
# ('Futrelle', 'Harder')
# ('Futrelle', 'Harper')
# ('Futrelle', 'Hassab')
# ('Futrelle', 'Hays')
# ('Futrelle', 'Hedman')
# ('Futrelle', 'Heikkinen')
# ('Futrelle', 'Herman')
# ('Futrelle', 'Hewlett')
# ('Futrelle', 'Hippach')
# ('Futrelle', 'Hirvonen')
# ('Futrelle', 'Hogeboom')
# ('Futrelle', 'Homer')
# ('Futrelle', 'Honkanen')
# ('Futrelle', 'Hosono')
# ('Futrelle', 'Hoyt')
# ('Futrelle', 'Icard')
# ('Futrelle', 'Ilett')
# ('Futrelle', 'Jalsevac')
# ('Futrelle', 'Jansson')
# ('Futrelle', 'Jerwan')
# ('Futrelle', 'Johnson')
# ('Futrelle', 'Jonsson')
# ('Futrelle', 'Karun')
# ('Futrelle', 'Kimball')
# ('Futrelle', 'Kink-Heilmann')
# ('Futrelle', 'Landergren')
# ('Futrelle', 'Lang')
# ('Futrelle', 'Laroche')
# ('Futrelle', 'LeRoy')
# ('Futrelle', 'Leader')
# ('Futrelle', 'Leeni')
# ('Futrelle', 'Lehmann')
# ('Futrelle', 'Lemore')
# ('Futrelle', 'Lesurer')
# ('Futrelle', 'Lindqvist')
# ('Futrelle', 'Lines')
# ('Futrelle', 'Longley')
# ('Futrelle', 'Louch')
# ('Futrelle', 'Lulic')
# ('Futrelle', 'Lurette')
# ('Futrelle', 'Madill')
# ('Futrelle', 'Madsen')
# ('Futrelle', 'Maioni')
# ('Futrelle', 'Mayne')
# ('Futrelle', 'McGough')
# ('Futrelle', 'McGowan')
# ('Futrelle', 'Mellinger')
# ('Futrelle', 'Mellors')
# ('Futrelle', 'Moor')
# ('Futrelle', 'Najib')
# ('Futrelle', 'Nakid')
# ('Futrelle', 'Nasser')
# ('Futrelle', 'Newell')
# ('Futrelle', 'Newsom')
# ('Futrelle', 'Nicola-Yarred')
# ('Futrelle', 'Nilsson')
# ('Futrelle', 'Niskanen')
# ('Futrelle', 'Nye')
# ('Futrelle', 'Nysten')
# ('Futrelle', 'Ohman')
# ('Futrelle', 'Osman')
# ('Futrelle', 'Parrish')
# ('Futrelle', 'Pears')
# ('Futrelle', 'Penasco y Castellana')
# ('Futrelle', 'Perreault')
# ('Futrelle', 'Persson')
# ('Futrelle', 'Peuchen')
# ('Futrelle', 'Phillips')
# ('Futrelle', 'Pickard')
# ('Futrelle', 'Pinsky')
# ('Futrelle', 'Potter')
# ('Futrelle', 'Quick')
# ('Futrelle', 'Reynaldo')
# ('Futrelle', 'Richards')
# ('Futrelle', 'Ridsdale')
# ('Futrelle', 'Robert')
# ('Futrelle', 'Romaine')
# ('Futrelle', 'Rothes')
# ('Futrelle', 'Rothschild')
# ('Futrelle', 'Rugg')
# ('Futrelle', 'Ryerson')
# ('Futrelle', 'Sagesser')
# ('Futrelle', 'Salkjelsvik')
# ('Futrelle', 'Sandstrom')
# ('Futrelle', 'Serepeca')
# ('Futrelle', 'Seward')
# ('Futrelle', 'Sheerlinck')
# ('Futrelle', 'Shelley')
# ('Futrelle', 'Shutes')
# ('Futrelle', 'Silven')
# ('Futrelle', 'Silverthorne')
# ('Futrelle', 'Simonius-Blumer')
# ('Futrelle', 'Sinkkonen')
# ('Futrelle', 'Sjoblom')
# ('Futrelle', 'Slayter')
# ('Futrelle', 'Sloper')
# ('Futrelle', 'Spedden')
# ('Futrelle', 'Stahelin-Maeglin')
# ('Futrelle', 'Stephenson')
# ('Futrelle', 'Stone')
# ('Futrelle', 'Stranden')
# ('Futrelle', 'Sunderland')
# ('Futrelle', 'Sundman')
# ('Futrelle', 'Swift')
# ('Futrelle', 'Taylor')
# ('Futrelle', 'Thayer')
# ('Futrelle', 'Thomas')
# ('Futrelle', 'Toomey')
# ('Futrelle', 'Tornquist')
# ('Futrelle', 'Touma')
# ('Futrelle', 'Trout')
# ('Futrelle', 'Troutt')
# ('Futrelle', 'Turja')
# ('Futrelle', 'Turkula')
# ('Futrelle', 'Ward')
# ('Futrelle', 'Warren')
# ('Futrelle', 'Watt')
# ('Futrelle', 'Webber')
# ('Futrelle', 'Weisz')
# ('Futrelle', 'Wells')
# ('Futrelle', 'West')
# ('Futrelle', 'Wick')
# ('Futrelle', 'Wilhelms')
# ('Futrelle', 'Young')
# ('Futrelle', 'de Messemaeker')
# ('Futrelle', 'de Mulder')
# ('Johnson', 'Jonsson')
# ('Johnson', 'Karun')
# ('Johnson', 'Kimball')
# ('Johnson', 'Kink-Heilmann')
# ('Johnson', 'Landergren')
# ('Johnson', 'Lang')
# ('Johnson', 'Laroche')
# ('Johnson', 'LeRoy')
# ('Johnson', 'Leader')
# ('Johnson', 'Leeni')
# ('Johnson', 'Lehmann')
# ('Johnson', 'Lemore')
# ('Johnson', 'Lesurer')
# ('Johnson', 'Lindqvist')
# ('Johnson', 'Lines')
# ('Johnson', 'Longley')
# ('Johnson', 'Louch')
# ('Johnson', 'Lulic')
# ('Johnson', 'Lurette')
# ('Johnson', 'Madill')
# ('Johnson', 'Madsen')
# ('Johnson', 'Maioni')
# ('Johnson', 'Mayne')
# ('Johnson', 'McGough')
# ('Johnson', 'McGowan')
# ('Johnson', 'Mellinger')
# ('Johnson', 'Mellors')
# ('Johnson', 'Moor')
# ('Johnson', 'Najib')
# ('Johnson', 'Nakid')
# ('Johnson', 'Nasser')
# ('Johnson', 'Newell')
# ('Johnson', 'Newsom')
# ('Johnson', 'Nicola-Yarred')
# ('Johnson', 'Nilsson')
# ('Johnson', 'Niskanen')
# ('Johnson', 'Nye')
# ('Johnson', 'Nysten')
# ('Johnson', 'Ohman')
# ('Johnson', 'Osman')
# ('Johnson', 'Parrish')
# ('Johnson', 'Pears')
# ('Johnson', 'Penasco y Castellana')
# ('Johnson', 'Perreault')
# ('Johnson', 'Persson')
# ('Johnson', 'Peuchen')
# ('Johnson', 'Phillips')
# ('Johnson', 'Pickard')
# ('Johnson', 'Pinsky')
# ('Johnson', 'Potter')
# ('Johnson', 'Quick')
# ('Johnson', 'Reynaldo')
# ('Johnson', 'Richards')
# ('Johnson', 'Ridsdale')
# ('Johnson', 'Robert')
# ('Johnson', 'Romaine')
# ('Johnson', 'Rothes')
# ('Johnson', 'Rothschild')
# ('Johnson', 'Rugg')
# ('Johnson', 'Ryerson')
# ('Johnson', 'Sagesser')
# ('Johnson', 'Salkjelsvik')
# ('Johnson', 'Sandstrom')
# ('Johnson', 'Serepeca')
# ('Johnson', 'Seward')
# ('Johnson', 'Sheerlinck')
# ('Johnson', 'Shelley')
# ('Johnson', 'Shutes')
# ('Johnson', 'Silven')
# ('Johnson', 'Silverthorne')
# ('Johnson', 'Simonius-Blumer')
# ('Johnson', 'Sinkkonen')
# ('Johnson', 'Sjoblom')
# ('Johnson', 'Slayter')
# ('Johnson', 'Sloper')
# ('Johnson', 'Spedden')
# ('Johnson', 'Stahelin-Maeglin')
# ('Johnson', 'Stephenson')
# ('Johnson', 'Stone')
# ('Johnson', 'Stranden')
# ('Johnson', 'Sunderland')
# ('Johnson', 'Sundman')
# ('Johnson', 'Swift')
# ('Johnson', 'Taylor')
# ('Johnson', 'Thayer')
# ('Johnson', 'Thomas')
# ('Johnson', 'Toomey')
# ('Johnson', 'Tornquist')
# ('Johnson', 'Touma')
# ('Johnson', 'Trout')
# ('Johnson', 'Troutt')
# ('Johnson', 'Turja')
# ('Johnson', 'Turkula')
# ('Johnson', 'Ward')
# ('Johnson', 'Warren')
# ('Johnson', 'Watt')
# ('Johnson', 'Webber')
# ('Johnson', 'Weisz')
# ('Johnson', 'Wells')
# ('Johnson', 'West')
# ('Johnson', 'Wick')
# ('Johnson', 'Wilhelms')
# ('Johnson', 'Young')
# ('Johnson', 'de Messemaeker')
# ('Johnson', 'de Mulder')
# ('Nasser', 'Newell')
# ('Nasser', 'Newsom')
# ('Nasser', 'Nicola-Yarred')
# ('Nasser', 'Nilsson')
# ('Nasser', 'Niskanen')
# ('Nasser', 'Nye')
# ('Nasser', 'Nysten')
# ('Nasser', 'Ohman')
# ('Nasser', 'Osman')
# ('Nasser', 'Parrish')
# ('Nasser', 'Pears')
# ('Nasser', 'Penasco y Castellana')
# ('Nasser', 'Perreault')
# ('Nasser', 'Persson')
# ('Nasser', 'Peuchen')
# ('Nasser', 'Phillips')
# ('Nasser', 'Pickard')
# ('Nasser', 'Pinsky')
# ('Nasser', 'Potter')
# ('Nasser', 'Quick')
# ('Nasser', 'Reynaldo')
# ('Nasser', 'Richards')
# ('Nasser', 'Ridsdale')
# ('Nasser', 'Robert')
# ('Nasser', 'Romaine')
# ('Nasser', 'Rothes')
# ('Nasser', 'Rothschild')
# ('Nasser', 'Rugg')
# ('Nasser', 'Ryerson')
# ('Nasser', 'Sagesser')
# ('Nasser', 'Salkjelsvik')
# ('Nasser', 'Sandstrom')
# ('Nasser', 'Serepeca')
# ('Nasser', 'Seward')
# ('Nasser', 'Sheerlinck')
# ('Nasser', 'Shelley')
# ('Nasser', 'Shutes')
# ('Nasser', 'Silven')
# ('Nasser', 'Silverthorne')
# ('Nasser', 'Simonius-Blumer')
# ('Nasser', 'Sinkkonen')
# ('Nasser', 'Sjoblom')
# ('Nasser', 'Slayter')
# ('Nasser', 'Sloper')
# ('Nasser', 'Spedden')
# ('Nasser', 'Stahelin-Maeglin')
# ('Nasser', 'Stephenson')
# ('Nasser', 'Stone')
# ('Nasser', 'Stranden')
# ('Nasser', 'Sunderland')
# ('Nasser', 'Sundman')
# ('Nasser', 'Swift')
# ('Nasser', 'Taylor')
# ('Nasser', 'Thayer')
# ('Nasser', 'Thomas')
# ('Nasser', 'Toomey')
# ('Nasser', 'Tornquist')
# ('Nasser', 'Touma')
# ('Nasser', 'Trout')
# ('Nasser', 'Troutt')
# ('Nasser', 'Turja')
# ('Nasser', 'Turkula')
# ('Nasser', 'Ward')
# ('Nasser', 'Warren')
# ('Nasser', 'Watt')
# ('Nasser', 'Webber')
# ('Nasser', 'Weisz')
# ('Nasser', 'Wells')
# ('Nasser', 'West')
# ('Nasser', 'Wick')
# ('Nasser', 'Wilhelms')
# ('Nasser', 'Young')
# ('Nasser', 'de Messemaeker')
# ('Nasser', 'de Mulder')
# ('Sandstrom', 'Serepeca')
# ('Sandstrom', 'Seward')
# ('Sandstrom', 'Sheerlinck')
# ('Sandstrom', 'Shelley')
# ('Sandstrom', 'Shutes')
# ('Sandstrom', 'Silven')
# ('Sandstrom', 'Silverthorne')
# ('Sandstrom', 'Simonius-Blumer')
# ('Sandstrom', 'Sinkkonen')
# ('Sandstrom', 'Sjoblom')
# ('Sandstrom', 'Slayter')
# ('Sandstrom', 'Sloper')
# ('Sandstrom', 'Spedden')
# ('Sandstrom', 'Stahelin-Maeglin')
# ('Sandstrom', 'Stephenson')
# ('Sandstrom', 'Stone')
# ('Sandstrom', 'Stranden')
# ('Sandstrom', 'Sunderland')
# ('Sandstrom', 'Sundman')
# ('Sandstrom', 'Swift')
# ('Sandstrom', 'Taylor')
# ('Sandstrom', 'Thayer')
# ('Sandstrom', 'Thomas')
# ('Sandstrom', 'Toomey')
# ('Sandstrom', 'Tornquist')
# ('Sandstrom', 'Touma')
# ('Sandstrom', 'Trout')
# ('Sandstrom', 'Troutt')
# ('Sandstrom', 'Turja')
# ('Sandstrom', 'Turkula')
# ('Sandstrom', 'Ward')
# ('Sandstrom', 'Warren')
# ('Sandstrom', 'Watt')
# ('Sandstrom', 'Webber')
# ('Sandstrom', 'Weisz')
# ('Sandstrom', 'Wells')
# ('Sandstrom', 'West')
# ('Sandstrom', 'Wick')
# ('Sandstrom', 'Wilhelms')
# ('Sandstrom', 'Young')
# ('Sandstrom', 'de Messemaeker')
# ('Sandstrom', 'de Mulder')
# ('Bonnell', 'Bowerman')
# ('Bonnell', 'Brown')
# ('Bonnell', 'Burns')
# ('Bonnell', 'Buss')
# ('Bonnell', 'Bystrom')
# ('Bonnell', 'Calderhead')
# ('Bonnell', 'Caldwell')
# ('Bonnell', 'Cameron')
# ('Bonnell', 'Cardeza')
# ('Bonnell', 'Carr')
# ('Bonnell', 'Chambers')
# ('Bonnell', 'Cherry')
# ('Bonnell', 'Chip')
# ('Bonnell', 'Christy')
# ('Bonnell', 'Clarke')
# ('Bonnell', 'Cleaver')
# ('Bonnell', 'Cohen')
# ('Bonnell', 'Collyer')
# ('Bonnell', 'Compton')
# ('Bonnell', 'Connolly')
# ('Bonnell', 'Coutts')
# ('Bonnell', 'Crosby')
# ('Bonnell', 'Cumings')
# ('Bonnell', 'Dahl')
# ('Bonnell', 'Daly')
# ('Bonnell', 'Daniel')
# ('Bonnell', 'Davis')
# ('Bonnell', 'Devaney')
# ('Bonnell', 'Dick')
# ('Bonnell', 'Dodge')
# ('Bonnell', 'Doling')
# ('Bonnell', 'Dorking')
# ('Bonnell', 'Dowdell')
# ('Bonnell', 'Drew')
# ('Bonnell', 'Duff Gordon')
# ('Bonnell', 'Duran y More')
# ('Bonnell', 'Emanuel')
# ('Bonnell', 'Endres')
# ('Bonnell', 'Eustis')
# ('Bonnell', 'Faunthorpe')
# ('Bonnell', 'Flynn')
# ('Bonnell', 'Francatelli')
# ('Bonnell', 'Frauenthal')
# ('Bonnell', 'Frolicher')
# ('Bonnell', 'Frolicher-Stehli')
# ('Bonnell', 'Futrelle')
# ('Bonnell', 'Garside')
# ('Bonnell', 'Gilnagh')
# ('Bonnell', 'Goldenberg')
# ('Bonnell', 'Goldsmith')
# ('Bonnell', 'Graham')
# ('Bonnell', 'Greenfield')
# ('Bonnell', 'Hakkarainen')
# ('Bonnell', 'Hamalainen')
# ('Bonnell', 'Harder')
# ('Bonnell', 'Harper')
# ('Bonnell', 'Hassab')
# ('Bonnell', 'Hays')
# ('Bonnell', 'Hedman')
# ('Bonnell', 'Heikkinen')
# ('Bonnell', 'Herman')
# ('Bonnell', 'Hewlett')
# ('Bonnell', 'Hippach')
# ('Bonnell', 'Hirvonen')
# ('Bonnell', 'Hogeboom')
# ('Bonnell', 'Homer')
# ('Bonnell', 'Honkanen')
# ('Bonnell', 'Hosono')
# ('Bonnell', 'Hoyt')
# ('Bonnell', 'Icard')
# ('Bonnell', 'Ilett')
# ('Bonnell', 'Jalsevac')
# ('Bonnell', 'Jansson')
# ('Bonnell', 'Jerwan')
# ('Bonnell', 'Johnson')
# ('Bonnell', 'Jonsson')
# ('Bonnell', 'Karun')
# ('Bonnell', 'Kimball')
# ('Bonnell', 'Kink-Heilmann')
# ('Bonnell', 'Landergren')
# ('Bonnell', 'Lang')
# ('Bonnell', 'Laroche')
# ('Bonnell', 'LeRoy')
# ('Bonnell', 'Leader')
# ('Bonnell', 'Leeni')
# ('Bonnell', 'Lehmann')
# ('Bonnell', 'Lemore')
# ('Bonnell', 'Lesurer')
# ('Bonnell', 'Lindqvist')
# ('Bonnell', 'Lines')
# ('Bonnell', 'Longley')
# ('Bonnell', 'Louch')
# ('Bonnell', 'Lulic')
# ('Bonnell', 'Lurette')
# ('Bonnell', 'Madill')
# ('Bonnell', 'Madsen')
# ('Bonnell', 'Maioni')
# ('Bonnell', 'Mayne')
# ('Bonnell', 'McGough')
# ('Bonnell', 'McGowan')
# ('Bonnell', 'Mellinger')
# ('Bonnell', 'Mellors')
# ('Bonnell', 'Moor')
# ('Bonnell', 'Najib')
# ('Bonnell', 'Nakid')
# ('Bonnell', 'Nasser')
# ('Bonnell', 'Newell')
# ('Bonnell', 'Newsom')
# ('Bonnell', 'Nicola-Yarred')
# ('Bonnell', 'Nilsson')
# ('Bonnell', 'Niskanen')
# ('Bonnell', 'Nye')
# ('Bonnell', 'Nysten')
# ('Bonnell', 'Ohman')
# ('Bonnell', 'Osman')
# ('Bonnell', 'Parrish')
# ('Bonnell', 'Pears')
# ('Bonnell', 'Penasco y Castellana')
# ('Bonnell', 'Perreault')
# ('Bonnell', 'Persson')
# ('Bonnell', 'Peuchen')
# ('Bonnell', 'Phillips')
# ('Bonnell', 'Pickard')
# ('Bonnell', 'Pinsky')
# ('Bonnell', 'Potter')
# ('Bonnell', 'Quick')
# ('Bonnell', 'Reynaldo')
# ('Bonnell', 'Richards')
# ('Bonnell', 'Ridsdale')
# ('Bonnell', 'Robert')
# ('Bonnell', 'Romaine')
# ('Bonnell', 'Rothes')
# ('Bonnell', 'Rothschild')
# ('Bonnell', 'Rugg')
# ('Bonnell', 'Ryerson')
# ('Bonnell', 'Sagesser')
# ('Bonnell', 'Salkjelsvik')
# ('Bonnell', 'Sandstrom')
# ('Bonnell', 'Serepeca')
# ('Bonnell', 'Seward')
# ('Bonnell', 'Sheerlinck')
# ('Bonnell', 'Shelley')
# ('Bonnell', 'Shutes')
# ('Bonnell', 'Silven')
# ('Bonnell', 'Silverthorne')
# ('Bonnell', 'Simonius-Blumer')
# ('Bonnell', 'Sinkkonen')
# ('Bonnell', 'Sjoblom')
# ('Bonnell', 'Slayter')
# ('Bonnell', 'Sloper')
# ('Bonnell', 'Spedden')
# ('Bonnell', 'Stahelin-Maeglin')
# ('Bonnell', 'Stephenson')
# ('Bonnell', 'Stone')
# ('Bonnell', 'Stranden')
# ('Bonnell', 'Sunderland')
# ('Bonnell', 'Sundman')
# ('Bonnell', 'Swift')
# ('Bonnell', 'Taylor')
# ('Bonnell', 'Thayer')
# ('Bonnell', 'Thomas')
# ('Bonnell', 'Toomey')
# ('Bonnell', 'Tornquist')
# ('Bonnell', 'Touma')
# ('Bonnell', 'Trout')
# ('Bonnell', 'Troutt')
# ('Bonnell', 'Turja')
# ('Bonnell', 'Turkula')
# ('Bonnell', 'Ward')
# ('Bonnell', 'Warren')
# ('Bonnell', 'Watt')
# ('Bonnell', 'Webber')
# ('Bonnell', 'Weisz')
# ('Bonnell', 'Wells')
# ('Bonnell', 'West')
# ('Bonnell', 'Wick')
# ('Bonnell', 'Wilhelms')
# ('Bonnell', 'Young')
# ('Bonnell', 'de Messemaeker')
# ('Bonnell', 'de Mulder')
# ('Hewlett', 'Hippach')
# ('Hewlett', 'Hirvonen')
# ('Hewlett', 'Hogeboom')
# ('Hewlett', 'Homer')
# ('Hewlett', 'Honkanen')
# ('Hewlett', 'Hosono')
# ('Hewlett', 'Hoyt')
# ('Hewlett', 'Icard')
# ('Hewlett', 'Ilett')
# ('Hewlett', 'Jalsevac')
# ('Hewlett', 'Jansson')
# ('Hewlett', 'Jerwan')
# ('Hewlett', 'Johnson')
# ('Hewlett', 'Jonsson')
# ('Hewlett', 'Karun')
# ('Hewlett', 'Kimball')
# ('Hewlett', 'Kink-Heilmann')
# ('Hewlett', 'Landergren')
# ('Hewlett', 'Lang')
# ('Hewlett', 'Laroche')
# ('Hewlett', 'LeRoy')
# ('Hewlett', 'Leader')
# ('Hewlett', 'Leeni')
# ('Hewlett', 'Lehmann')
# ('Hewlett', 'Lemore')
# ('Hewlett', 'Lesurer')
# ('Hewlett', 'Lindqvist')
# ('Hewlett', 'Lines')
# ('Hewlett', 'Longley')
# ('Hewlett', 'Louch')
# ('Hewlett', 'Lulic')
# ('Hewlett', 'Lurette')
# ('Hewlett', 'Madill')
# ('Hewlett', 'Madsen')
# ('Hewlett', 'Maioni')
# ('Hewlett', 'Mayne')
# ('Hewlett', 'McGough')
# ('Hewlett', 'McGowan')
# ('Hewlett', 'Mellinger')
# ('Hewlett', 'Mellors')
# ('Hewlett', 'Moor')
# ('Hewlett', 'Najib')
# ('Hewlett', 'Nakid')
# ('Hewlett', 'Nasser')
# ('Hewlett', 'Newell')
# ('Hewlett', 'Newsom')
# ('Hewlett', 'Nicola-Yarred')
# ('Hewlett', 'Nilsson')
# ('Hewlett', 'Niskanen')
# ('Hewlett', 'Nye')
# ('Hewlett', 'Nysten')
# ('Hewlett', 'Ohman')
# ('Hewlett', 'Osman')
# ('Hewlett', 'Parrish')
# ('Hewlett', 'Pears')
# ('Hewlett', 'Penasco y Castellana')
# ('Hewlett', 'Perreault')
# ('Hewlett', 'Persson')
# ('Hewlett', 'Peuchen')
# ('Hewlett', 'Phillips')
# ('Hewlett', 'Pickard')
# ('Hewlett', 'Pinsky')
# ('Hewlett', 'Potter')
# ('Hewlett', 'Quick')
# ('Hewlett', 'Reynaldo')
# ('Hewlett', 'Richards')
# ('Hewlett', 'Ridsdale')
# ('Hewlett', 'Robert')
# ('Hewlett', 'Romaine')
# ('Hewlett', 'Rothes')
# ('Hewlett', 'Rothschild')
# ('Hewlett', 'Rugg')
# ('Hewlett', 'Ryerson')
# ('Hewlett', 'Sagesser')
# ('Hewlett', 'Salkjelsvik')
# ('Hewlett', 'Sandstrom')
# ('Hewlett', 'Serepeca')
# ('Hewlett', 'Seward')
# ('Hewlett', 'Sheerlinck')
# ('Hewlett', 'Shelley')
# ('Hewlett', 'Shutes')
# ('Hewlett', 'Silven')
# ('Hewlett', 'Silverthorne')
# ('Hewlett', 'Simonius-Blumer')
# ('Hewlett', 'Sinkkonen')
# ('Hewlett', 'Sjoblom')
# ('Hewlett', 'Slayter')
# ('Hewlett', 'Sloper')
# ('Hewlett', 'Spedden')
# ('Hewlett', 'Stahelin-Maeglin')
# ('Hewlett', 'Stephenson')
# ('Hewlett', 'Stone')
# ('Hewlett', 'Stranden')
# ('Hewlett', 'Sunderland')
# ('Hewlett', 'Sundman')
# ('Hewlett', 'Swift')
# ('Hewlett', 'Taylor')
# ('Hewlett', 'Thayer')
# ('Hewlett', 'Thomas')
# ('Hewlett', 'Toomey')
# ('Hewlett', 'Tornquist')
# ('Hewlett', 'Touma')
# ('Hewlett', 'Trout')
# ('Hewlett', 'Troutt')
# ('Hewlett', 'Turja')
# ('Hewlett', 'Turkula')
# ('Hewlett', 'Ward')
# ('Hewlett', 'Warren')
# ('Hewlett', 'Watt')
# ('Hewlett', 'Webber')
# ('Hewlett', 'Weisz')
# ('Hewlett', 'Wells')
# ('Hewlett', 'West')
# ('Hewlett', 'Wick')
# ('Hewlett', 'Wilhelms')
# ('Hewlett', 'Young')
# ('Hewlett', 'de Messemaeker')
# ('Hewlett', 'de Mulder')
# ('Beesley', 'Behr')
# ('Beesley', 'Bidois')
# ('Beesley', 'Bing')
# ('Beesley', 'Bishop')
# ('Beesley', 'Bissette')
# ('Beesley', 'Bjornstrom-Steffansson')
# ('Beesley', 'Blank')
# ('Beesley', 'Bonnell')
# ('Beesley', 'Bowerman')
# ('Beesley', 'Brown')
# ('Beesley', 'Burns')
# ('Beesley', 'Buss')
# ('Beesley', 'Bystrom')
# ('Beesley', 'Calderhead')
# ('Beesley', 'Caldwell')
# ('Beesley', 'Cameron')
# ('Beesley', 'Cardeza')
# ('Beesley', 'Carr')
# ('Beesley', 'Chambers')
# ('Beesley', 'Cherry')
# ('Beesley', 'Chip')
# ('Beesley', 'Christy')
# ('Beesley', 'Clarke')
# ('Beesley', 'Cleaver')
# ('Beesley', 'Cohen')
# ('Beesley', 'Collyer')
# ('Beesley', 'Compton')
# ('Beesley', 'Connolly')
# ('Beesley', 'Coutts')
# ('Beesley', 'Crosby')
# ('Beesley', 'Cumings')
# ('Beesley', 'Dahl')
# ('Beesley', 'Daly')
# ('Beesley', 'Daniel')
# ('Beesley', 'Davis')
# ('Beesley', 'Devaney')
# ('Beesley', 'Dick')
# ('Beesley', 'Dodge')
# ('Beesley', 'Doling')
# ('Beesley', 'Dorking')
# ('Beesley', 'Dowdell')
# ('Beesley', 'Drew')
# ('Beesley', 'Duff Gordon')
# ('Beesley', 'Duran y More')
# ('Beesley', 'Emanuel')
# ('Beesley', 'Endres')
# ('Beesley', 'Eustis')
# ('Beesley', 'Faunthorpe')
# ('Beesley', 'Flynn')
# ('Beesley', 'Francatelli')
# ('Beesley', 'Frauenthal')
# ('Beesley', 'Frolicher')
# ('Beesley', 'Frolicher-Stehli')
# ('Beesley', 'Futrelle')
# ('Beesley', 'Garside')
# ('Beesley', 'Gilnagh')
# ('Beesley', 'Goldenberg')
# ('Beesley', 'Goldsmith')
# ('Beesley', 'Graham')
# ('Beesley', 'Greenfield')
# ('Beesley', 'Hakkarainen')
# ('Beesley', 'Hamalainen')
# ('Beesley', 'Harder')
# ('Beesley', 'Harper')
# ('Beesley', 'Hassab')
# ('Beesley', 'Hays')
# ('Beesley', 'Hedman')
# ('Beesley', 'Heikkinen')
# ('Beesley', 'Herman')
# ('Beesley', 'Hewlett')
# ('Beesley', 'Hippach')
# ('Beesley', 'Hirvonen')
# ('Beesley', 'Hogeboom')
# ('Beesley', 'Homer')
# ('Beesley', 'Honkanen')
# ('Beesley', 'Hosono')
# ('Beesley', 'Hoyt')
# ('Beesley', 'Icard')
# ('Beesley', 'Ilett')
# ('Beesley', 'Jalsevac')
# ('Beesley', 'Jansson')
# ('Beesley', 'Jerwan')
# ('Beesley', 'Johnson')
# ('Beesley', 'Jonsson')
# ('Beesley', 'Karun')
# ('Beesley', 'Kimball')
# ('Beesley', 'Kink-Heilmann')
# ('Beesley', 'Landergren')
# ('Beesley', 'Lang')
# ('Beesley', 'Laroche')
# ('Beesley', 'LeRoy')
# ('Beesley', 'Leader')
# ('Beesley', 'Leeni')
# ('Beesley', 'Lehmann')
# ('Beesley', 'Lemore')
# ('Beesley', 'Lesurer')
# ('Beesley', 'Lindqvist')
# ('Beesley', 'Lines')
# ('Beesley', 'Longley')
# ('Beesley', 'Louch')
# ('Beesley', 'Lulic')
# ('Beesley', 'Lurette')
# ('Beesley', 'Madill')
# ('Beesley', 'Madsen')
# ('Beesley', 'Maioni')
# ('Beesley', 'Mayne')
# ('Beesley', 'McGough')
# ('Beesley', 'McGowan')
# ('Beesley', 'Mellinger')
# ('Beesley', 'Mellors')
# ('Beesley', 'Moor')
# ('Beesley', 'Najib')
# ('Beesley', 'Nakid')
# ('Beesley', 'Nasser')
# ('Beesley', 'Newell')
# ('Beesley', 'Newsom')
# ('Beesley', 'Nicola-Yarred')
# ('Beesley', 'Nilsson')
# ('Beesley', 'Niskanen')
# ('Beesley', 'Nye')
# ('Beesley', 'Nysten')
# ('Beesley', 'Ohman')
# ('Beesley', 'Osman')
# ('Beesley', 'Parrish')
# ('Beesley', 'Pears')
# ('Beesley', 'Penasco y Castellana')
# ('Beesley', 'Perreault')
# ('Beesley', 'Persson')
# ('Beesley', 'Peuchen')
# ('Beesley', 'Phillips')
# ('Beesley', 'Pickard')
# ('Beesley', 'Pinsky')
# ('Beesley', 'Potter')
# ('Beesley', 'Quick')
# ('Beesley', 'Reynaldo')
# ('Beesley', 'Richards')
# ('Beesley', 'Ridsdale')
# ('Beesley', 'Robert')
# ('Beesley', 'Romaine')
# ('Beesley', 'Rothes')
# ('Beesley', 'Rothschild')
# ('Beesley', 'Rugg')
# ('Beesley', 'Ryerson')
# ('Beesley', 'Sagesser')
# ('Beesley', 'Salkjelsvik')
# ('Beesley', 'Sandstrom')
# ('Beesley', 'Serepeca')
# ('Beesley', 'Seward')
# ('Beesley', 'Sheerlinck')
# ('Beesley', 'Shelley')
# ('Beesley', 'Shutes')
# ('Beesley', 'Silven')
# ('Beesley', 'Silverthorne')
# ('Beesley', 'Simonius-Blumer')
# ('Beesley', 'Sinkkonen')
# ('Beesley', 'Sjoblom')
# ('Beesley', 'Slayter')
# ('Beesley', 'Sloper')
# ('Beesley', 'Spedden')
# ('Beesley', 'Stahelin-Maeglin')
# ('Beesley', 'Stephenson')
# ('Beesley', 'Stone')
# ('Beesley', 'Stranden')
# ('Beesley', 'Sunderland')
# ('Beesley', 'Sundman')
# ('Beesley', 'Swift')
# ('Beesley', 'Taylor')
# ('Beesley', 'Thayer')
# ('Beesley', 'Thomas')
# ('Beesley', 'Toomey')
# ('Beesley', 'Tornquist')
# ('Beesley', 'Touma')
# ('Beesley', 'Trout')
# ('Beesley', 'Troutt')
# ('Beesley', 'Turja')
# ('Beesley', 'Turkula')
# ('Beesley', 'Ward')
# ('Beesley', 'Warren')
# ('Beesley', 'Watt')
# ('Beesley', 'Webber')
# ('Beesley', 'Weisz')
# ('Beesley', 'Wells')
# ('Beesley', 'West')
# ('Beesley', 'Wick')
# ('Beesley', 'Wilhelms')
# ('Beesley', 'Young')
# ('Beesley', 'de Messemaeker')
# ('Beesley', 'de Mulder')
# ('McGowan', 'Mellinger')
# ('McGowan', 'Mellors')
# ('McGowan', 'Moor')
# ('McGowan', 'Najib')
# ('McGowan', 'Nakid')
# ('McGowan', 'Nasser')
# ('McGowan', 'Newell')
# ('McGowan', 'Newsom')
# ('McGowan', 'Nicola-Yarred')
# ('McGowan', 'Nilsson')
# ('McGowan', 'Niskanen')
# ('McGowan', 'Nye')
# ('McGowan', 'Nysten')
# ('McGowan', 'Ohman')
# ('McGowan', 'Osman')
# ('McGowan', 'Parrish')
# ('McGowan', 'Pears')
# ('McGowan', 'Penasco y Castellana')
# ('McGowan', 'Perreault')
# ('McGowan', 'Persson')
# ('McGowan', 'Peuchen')
# ('McGowan', 'Phillips')
# ('McGowan', 'Pickard')
# ('McGowan', 'Pinsky')
# ('McGowan', 'Potter')
# ('McGowan', 'Quick')
# ('McGowan', 'Reynaldo')
# ('McGowan', 'Richards')
# ('McGowan', 'Ridsdale')
# ('McGowan', 'Robert')
# ('McGowan', 'Romaine')
# ('McGowan', 'Rothes')
# ('McGowan', 'Rothschild')
# ('McGowan', 'Rugg')
# ('McGowan', 'Ryerson')
# ('McGowan', 'Sagesser')
# ('McGowan', 'Salkjelsvik')
# ('McGowan', 'Sandstrom')
# ('McGowan', 'Serepeca')
# ('McGowan', 'Seward')
# ('McGowan', 'Sheerlinck')
# ('McGowan', 'Shelley')
# ('McGowan', 'Shutes')
# ('McGowan', 'Silven')
# ('McGowan', 'Silverthorne')
# ('McGowan', 'Simonius-Blumer')
# ('McGowan', 'Sinkkonen')
# ('McGowan', 'Sjoblom')
# ('McGowan', 'Slayter')
# ('McGowan', 'Sloper')
# ('McGowan', 'Spedden')
# ('McGowan', 'Stahelin-Maeglin')
# ('McGowan', 'Stephenson')
# ('McGowan', 'Stone')
# ('McGowan', 'Stranden')
# ('McGowan', 'Sunderland')
# ('McGowan', 'Sundman')
# ('McGowan', 'Swift')
# ('McGowan', 'Taylor')
# ('McGowan', 'Thayer')
# ('McGowan', 'Thomas')
# ('McGowan', 'Toomey')
# ('McGowan', 'Tornquist')
# ('McGowan', 'Touma')
# ('McGowan', 'Trout')
# ('McGowan', 'Troutt')
# ('McGowan', 'Turja')
# ('McGowan', 'Turkula')
# ('McGowan', 'Ward')
# ('McGowan', 'Warren')
# ('McGowan', 'Watt')
# ('McGowan', 'Webber')
# ('McGowan', 'Weisz')
# ('McGowan', 'Wells')
# ('McGowan', 'West')
# ('McGowan', 'Wick')
# ('McGowan', 'Wilhelms')
# ('McGowan', 'Young')
# ('McGowan', 'de Messemaeker')
# ('McGowan', 'de Mulder')
# ('Sloper', 'Spedden')
# ('Sloper', 'Stahelin-Maeglin')
# ('Sloper', 'Stephenson')
# ('Sloper', 'Stone')
# ('Sloper', 'Stranden')
# ('Sloper', 'Sunderland')
# ('Sloper', 'Sundman')
# ('Sloper', 'Swift')
# ('Sloper', 'Taylor')
# ('Sloper', 'Thayer')
# ('Sloper', 'Thomas')
# ('Sloper', 'Toomey')
# ('Sloper', 'Tornquist')
# ('Sloper', 'Touma')
# ('Sloper', 'Trout')
# ('Sloper', 'Troutt')
# ('Sloper', 'Turja')
# ('Sloper', 'Turkula')
# ('Sloper', 'Ward')
# ('Sloper', 'Warren')
# ('Sloper', 'Watt')
# ('Sloper', 'Webber')
# ('Sloper', 'Weisz')
# ('Sloper', 'Wells')
# ('Sloper', 'West')
# ('Sloper', 'Wick')
# ('Sloper', 'Wilhelms')
# ('Sloper', 'Young')
# ('Sloper', 'de Messemaeker')
# ('Sloper', 'de Mulder')
# ('Asplund', 'Astor')
# ('Asplund', 'Aubart')
# ('Asplund', 'Ayoub')
# ('Asplund', 'Backstrom')
# ('Asplund', 'Baclini')
# ('Asplund', 'Ball')
# ('Asplund', 'Barah')
# ('Asplund', 'Barber')
# ('Asplund', 'Barkworth')
# ('Asplund', 'Bazzani')
# ('Asplund', 'Beane')
# ('Asplund', 'Becker')
# ('Asplund', 'Beckwith')
# ('Asplund', 'Beesley')
# ('Asplund', 'Behr')
# ('Asplund', 'Bidois')
# ('Asplund', 'Bing')
# ('Asplund', 'Bishop')
# ('Asplund', 'Bissette')
# ('Asplund', 'Bjornstrom-Steffansson')
# ('Asplund', 'Blank')
# ('Asplund', 'Bonnell')
# ('Asplund', 'Bowerman')
# ('Asplund', 'Brown')
# ('Asplund', 'Burns')
# ('Asplund', 'Buss')
# ('Asplund', 'Bystrom')
# ('Asplund', 'Calderhead')
# ('Asplund', 'Caldwell')
# ('Asplund', 'Cameron')
# ('Asplund', 'Cardeza')
# ('Asplund', 'Carr')
# ('Asplund', 'Chambers')
# ('Asplund', 'Cherry')
# ('Asplund', 'Chip')
# ('Asplund', 'Christy')
# ('Asplund', 'Clarke')
# ('Asplund', 'Cleaver')
# ('Asplund', 'Cohen')
# ('Asplund', 'Collyer')
# ('Asplund', 'Compton')
# ('Asplund', 'Connolly')
# ('Asplund', 'Coutts')
# ('Asplund', 'Crosby')
# ('Asplund', 'Cumings')
# ('Asplund', 'Dahl')
# ('Asplund', 'Daly')
# ('Asplund', 'Daniel')
# ('Asplund', 'Davis')
# ('Asplund', 'Devaney')
# ('Asplund', 'Dick')
# ('Asplund', 'Dodge')
# ('Asplund', 'Doling')
# ('Asplund', 'Dorking')
# ('Asplund', 'Dowdell')
# ('Asplund', 'Drew')
# ('Asplund', 'Duff Gordon')
# ('Asplund', 'Duran y More')
# ('Asplund', 'Emanuel')
# ('Asplund', 'Endres')
# ('Asplund', 'Eustis')
# ('Asplund', 'Faunthorpe')
# ('Asplund', 'Flynn')
# ('Asplund', 'Francatelli')
# ('Asplund', 'Frauenthal')
# ('Asplund', 'Frolicher')
# ('Asplund', 'Frolicher-Stehli')
# ('Asplund', 'Futrelle')
# ('Asplund', 'Garside')
# ('Asplund', 'Gilnagh')
# ('Asplund', 'Goldenberg')
# ('Asplund', 'Goldsmith')
# ('Asplund', 'Graham')
# ('Asplund', 'Greenfield')
# ('Asplund', 'Hakkarainen')
# ('Asplund', 'Hamalainen')
# ('Asplund', 'Harder')
# ('Asplund', 'Harper')
# ('Asplund', 'Hassab')
# ('Asplund', 'Hays')
# ('Asplund', 'Hedman')
# ('Asplund', 'Heikkinen')
# ('Asplund', 'Herman')
# ('Asplund', 'Hewlett')
# ('Asplund', 'Hippach')
# ('Asplund', 'Hirvonen')
# ('Asplund', 'Hogeboom')
# ('Asplund', 'Homer')
# ('Asplund', 'Honkanen')
# ('Asplund', 'Hosono')
# ('Asplund', 'Hoyt')
# ('Asplund', 'Icard')
# ('Asplund', 'Ilett')
# ('Asplund', 'Jalsevac')
# ('Asplund', 'Jansson')
# ('Asplund', 'Jerwan')
# ('Asplund', 'Johnson')
# ('Asplund', 'Jonsson')
# ('Asplund', 'Karun')
# ('Asplund', 'Kimball')
# ('Asplund', 'Kink-Heilmann')
# ('Asplund', 'Landergren')
# ('Asplund', 'Lang')
# ('Asplund', 'Laroche')
# ('Asplund', 'LeRoy')
# ('Asplund', 'Leader')
# ('Asplund', 'Leeni')
# ('Asplund', 'Lehmann')
# ('Asplund', 'Lemore')
# ('Asplund', 'Lesurer')
# ('Asplund', 'Lindqvist')
# ('Asplund', 'Lines')
# ('Asplund', 'Longley')
# ('Asplund', 'Louch')
# ('Asplund', 'Lulic')
# ('Asplund', 'Lurette')
# ('Asplund', 'Madill')
# ('Asplund', 'Madsen')
# ('Asplund', 'Maioni')
# ('Asplund', 'Mayne')
# ('Asplund', 'McGough')
# ('Asplund', 'McGowan')
# ('Asplund', 'Mellinger')
# ('Asplund', 'Mellors')
# ('Asplund', 'Moor')
# ('Asplund', 'Najib')
# ('Asplund', 'Nakid')
# ('Asplund', 'Nasser')
# ('Asplund', 'Newell')
# ('Asplund', 'Newsom')
# ('Asplund', 'Nicola-Yarred')
# ('Asplund', 'Nilsson')
# ('Asplund', 'Niskanen')
# ('Asplund', 'Nye')
# ('Asplund', 'Nysten')
# ('Asplund', 'Ohman')
# ('Asplund', 'Osman')
# ('Asplund', 'Parrish')
# ('Asplund', 'Pears')
# ('Asplund', 'Penasco y Castellana')
# ('Asplund', 'Perreault')
# ('Asplund', 'Persson')
# ('Asplund', 'Peuchen')
# ('Asplund', 'Phillips')
# ('Asplund', 'Pickard')
# ('Asplund', 'Pinsky')
# ('Asplund', 'Potter')
# ('Asplund', 'Quick')
# ('Asplund', 'Reynaldo')
# ('Asplund', 'Richards')
# ('Asplund', 'Ridsdale')
# ('Asplund', 'Robert')
# ('Asplund', 'Romaine')
# ('Asplund', 'Rothes')
# ('Asplund', 'Rothschild')
# ('Asplund', 'Rugg')
# ('Asplund', 'Ryerson')
# ('Asplund', 'Sagesser')
# ('Asplund', 'Salkjelsvik')
# ('Asplund', 'Sandstrom')
# ('Asplund', 'Serepeca')
# ('Asplund', 'Seward')
# ('Asplund', 'Sheerlinck')
# ('Asplund', 'Shelley')
# ('Asplund', 'Shutes')
# ('Asplund', 'Silven')
# ('Asplund', 'Silverthorne')
# ('Asplund', 'Simonius-Blumer')
# ('Asplund', 'Sinkkonen')
# ('Asplund', 'Sjoblom')
# ('Asplund', 'Slayter')
# ('Asplund', 'Sloper')
# ('Asplund', 'Spedden')
# ('Asplund', 'Stahelin-Maeglin')
# ('Asplund', 'Stephenson')
# ('Asplund', 'Stone')
# ('Asplund', 'Stranden')
# ('Asplund', 'Sunderland')
# ('Asplund', 'Sundman')
# ('Asplund', 'Swift')
# ('Asplund', 'Taylor')
# ('Asplund', 'Thayer')
# ('Asplund', 'Thomas')
# ('Asplund', 'Toomey')
# ('Asplund', 'Tornquist')
# ('Asplund', 'Touma')
# ('Asplund', 'Trout')
# ('Asplund', 'Troutt')
# ('Asplund', 'Turja')
# ('Asplund', 'Turkula')
# ('Asplund', 'Ward')
# ('Asplund', 'Warren')
# ('Asplund', 'Watt')
# ('Asplund', 'Webber')
# ('Asplund', 'Weisz')
# ('Asplund', 'Wells')
# ('Asplund', 'West')
# ('Asplund', 'Wick')
# ('Asplund', 'Wilhelms')
# ('Asplund', 'Young')
# ('Asplund', 'de Messemaeker')
# ('Asplund', 'de Mulder')
# ('Nicola-Yarred', 'Nilsson')
# ('Nicola-Yarred', 'Niskanen')
# ('Nicola-Yarred', 'Nye')
# ('Nicola-Yarred', 'Nysten')
# ('Nicola-Yarred', 'Ohman')
# ('Nicola-Yarred', 'Osman')
# ('Nicola-Yarred', 'Parrish')
# ('Nicola-Yarred', 'Pears')
# ('Nicola-Yarred', 'Penasco y Castellana')
# ('Nicola-Yarred', 'Perreault')
# ('Nicola-Yarred', 'Persson')
# ('Nicola-Yarred', 'Peuchen')
# ('Nicola-Yarred', 'Phillips')
# ('Nicola-Yarred', 'Pickard')
# ('Nicola-Yarred', 'Pinsky')
# ('Nicola-Yarred', 'Potter')
# ('Nicola-Yarred', 'Quick')
# ('Nicola-Yarred', 'Reynaldo')
# ('Nicola-Yarred', 'Richards')
# ('Nicola-Yarred', 'Ridsdale')
# ('Nicola-Yarred', 'Robert')
# ('Nicola-Yarred', 'Romaine')
# ('Nicola-Yarred', 'Rothes')
# ('Nicola-Yarred', 'Rothschild')
# ('Nicola-Yarred', 'Rugg')
# ('Nicola-Yarred', 'Ryerson')
# ('Nicola-Yarred', 'Sagesser')
# ('Nicola-Yarred', 'Salkjelsvik')
# ('Nicola-Yarred', 'Sandstrom')
# ('Nicola-Yarred', 'Serepeca')
# ('Nicola-Yarred', 'Seward')
# ('Nicola-Yarred', 'Sheerlinck')
# ('Nicola-Yarred', 'Shelley')
# ('Nicola-Yarred', 'Shutes')
# ('Nicola-Yarred', 'Silven')
# ('Nicola-Yarred', 'Silverthorne')
# ('Nicola-Yarred', 'Simonius-Blumer')
# ('Nicola-Yarred', 'Sinkkonen')
# ('Nicola-Yarred', 'Sjoblom')
# ('Nicola-Yarred', 'Slayter')
# ('Nicola-Yarred', 'Sloper')
# ('Nicola-Yarred', 'Spedden')
# ('Nicola-Yarred', 'Stahelin-Maeglin')
# ('Nicola-Yarred', 'Stephenson')
# ('Nicola-Yarred', 'Stone')
# ('Nicola-Yarred', 'Stranden')
# ('Nicola-Yarred', 'Sunderland')
# ('Nicola-Yarred', 'Sundman')
# ('Nicola-Yarred', 'Swift')
# ('Nicola-Yarred', 'Taylor')
# ('Nicola-Yarred', 'Thayer')
# ('Nicola-Yarred', 'Thomas')
# ('Nicola-Yarred', 'Toomey')
# ('Nicola-Yarred', 'Tornquist')
# ('Nicola-Yarred', 'Touma')
# ('Nicola-Yarred', 'Trout')
# ('Nicola-Yarred', 'Troutt')
# ('Nicola-Yarred', 'Turja')
# ('Nicola-Yarred', 'Turkula')
# ('Nicola-Yarred', 'Ward')
# ('Nicola-Yarred', 'Warren')
# ('Nicola-Yarred', 'Watt')
# ('Nicola-Yarred', 'Webber')
# ('Nicola-Yarred', 'Weisz')
# ('Nicola-Yarred', 'Wells')
# ('Nicola-Yarred', 'West')
# ('Nicola-Yarred', 'Wick')
# ('Nicola-Yarred', 'Wilhelms')
# ('Nicola-Yarred', 'Young')
# ('Nicola-Yarred', 'de Messemaeker')
# ('Nicola-Yarred', 'de Mulder')
# ('Laroche', 'LeRoy')
# ('Laroche', 'Leader')
# ('Laroche', 'Leeni')
# ('Laroche', 'Lehmann')
# ('Laroche', 'Lemore')
# ('Laroche', 'Lesurer')
# ('Laroche', 'Lindqvist')
# ('Laroche', 'Lines')
# ('Laroche', 'Longley')
# ('Laroche', 'Louch')
# ('Laroche', 'Lulic')
# ('Laroche', 'Lurette')
# ('Laroche', 'Madill')
# ('Laroche', 'Madsen')
# ('Laroche', 'Maioni')
# ('Laroche', 'Mayne')
# ('Laroche', 'McGough')
# ('Laroche', 'McGowan')
# ('Laroche', 'Mellinger')
# ('Laroche', 'Mellors')
# ('Laroche', 'Moor')
# ('Laroche', 'Najib')
# ('Laroche', 'Nakid')
# ('Laroche', 'Nasser')
# ('Laroche', 'Newell')
# ('Laroche', 'Newsom')
# ('Laroche', 'Nicola-Yarred')
# ('Laroche', 'Nilsson')
# ('Laroche', 'Niskanen')
# ('Laroche', 'Nye')
# ('Laroche', 'Nysten')
# ('Laroche', 'Ohman')
# ('Laroche', 'Osman')
# ('Laroche', 'Parrish')
# ('Laroche', 'Pears')
# ('Laroche', 'Penasco y Castellana')
# ('Laroche', 'Perreault')
# ('Laroche', 'Persson')
# ('Laroche', 'Peuchen')
# ('Laroche', 'Phillips')
# ('Laroche', 'Pickard')
# ('Laroche', 'Pinsky')
# ('Laroche', 'Potter')
# ('Laroche', 'Quick')
# ('Laroche', 'Reynaldo')
# ('Laroche', 'Richards')
# ('Laroche', 'Ridsdale')
# ('Laroche', 'Robert')
# ('Laroche', 'Romaine')
# ('Laroche', 'Rothes')
# ('Laroche', 'Rothschild')
# ('Laroche', 'Rugg')
# ('Laroche', 'Ryerson')
# ('Laroche', 'Sagesser')
# ('Laroche', 'Salkjelsvik')
# ('Laroche', 'Sandstrom')
# ('Laroche', 'Serepeca')
# ('Laroche', 'Seward')
# ('Laroche', 'Sheerlinck')
# ('Laroche', 'Shelley')
# ('Laroche', 'Shutes')
# ('Laroche', 'Silven')
# ('Laroche', 'Silverthorne')
# ('Laroche', 'Simonius-Blumer')
# ('Laroche', 'Sinkkonen')
# ('Laroche', 'Sjoblom')
# ('Laroche', 'Slayter')
# ('Laroche', 'Sloper')
# ('Laroche', 'Spedden')
# ('Laroche', 'Stahelin-Maeglin')
# ('Laroche', 'Stephenson')
# ('Laroche', 'Stone')
# ('Laroche', 'Stranden')
# ('Laroche', 'Sunderland')
# ('Laroche', 'Sundman')
# ('Laroche', 'Swift')
# ('Laroche', 'Taylor')
# ('Laroche', 'Thayer')
# ('Laroche', 'Thomas')
# ('Laroche', 'Toomey')
# ('Laroche', 'Tornquist')
# ('Laroche', 'Touma')
# ('Laroche', 'Trout')
# ('Laroche', 'Troutt')
# ('Laroche', 'Turja')
# ('Laroche', 'Turkula')
# ('Laroche', 'Ward')
# ('Laroche', 'Warren')
# ('Laroche', 'Watt')
# ('Laroche', 'Webber')
# ('Laroche', 'Weisz')
# ('Laroche', 'Wells')
# ('Laroche', 'West')
# ('Laroche', 'Wick')
# ('Laroche', 'Wilhelms')
# ('Laroche', 'Young')
# ('Laroche', 'de Messemaeker')
# ('Laroche', 'de Mulder')
# ('Devaney', 'Dick')
# ('Devaney', 'Dodge')
# ('Devaney', 'Doling')
# ('Devaney', 'Dorking')
# ('Devaney', 'Dowdell')
# ('Devaney', 'Drew')
# ('Devaney', 'Duff Gordon')
# ('Devaney', 'Duran y More')
# ('Devaney', 'Emanuel')
# ('Devaney', 'Endres')
# ('Devaney', 'Eustis')
# ('Devaney', 'Faunthorpe')
# ('Devaney', 'Flynn')
# ('Devaney', 'Francatelli')
# ('Devaney', 'Frauenthal')
# ('Devaney', 'Frolicher')
# ('Devaney', 'Frolicher-Stehli')
# ('Devaney', 'Futrelle')
# ('Devaney', 'Garside')
# ('Devaney', 'Gilnagh')
# ('Devaney', 'Goldenberg')
# ('Devaney', 'Goldsmith')
# ('Devaney', 'Graham')
# ('Devaney', 'Greenfield')
# ('Devaney', 'Hakkarainen')
# ('Devaney', 'Hamalainen')
# ('Devaney', 'Harder')
# ('Devaney', 'Harper')
# ('Devaney', 'Hassab')
# ('Devaney', 'Hays')
# ('Devaney', 'Hedman')
# ('Devaney', 'Heikkinen')
# ('Devaney', 'Herman')
# ('Devaney', 'Hewlett')
# ('Devaney', 'Hippach')
# ('Devaney', 'Hirvonen')
# ('Devaney', 'Hogeboom')
# ('Devaney', 'Homer')
# ('Devaney', 'Honkanen')
# ('Devaney', 'Hosono')
# ('Devaney', 'Hoyt')
# ('Devaney', 'Icard')
# ('Devaney', 'Ilett')
# ('Devaney', 'Jalsevac')
# ('Devaney', 'Jansson')
# ('Devaney', 'Jerwan')
# ('Devaney', 'Johnson')
# ('Devaney', 'Jonsson')
# ('Devaney', 'Karun')
# ('Devaney', 'Kimball')
# ('Devaney', 'Kink-Heilmann')
# ('Devaney', 'Landergren')
# ('Devaney', 'Lang')
# ('Devaney', 'Laroche')
# ('Devaney', 'LeRoy')
# ('Devaney', 'Leader')
# ('Devaney', 'Leeni')
# ('Devaney', 'Lehmann')
# ('Devaney', 'Lemore')
# ('Devaney', 'Lesurer')
# ('Devaney', 'Lindqvist')
# ('Devaney', 'Lines')
# ('Devaney', 'Longley')
# ('Devaney', 'Louch')
# ('Devaney', 'Lulic')
# ('Devaney', 'Lurette')
# ('Devaney', 'Madill')
# ('Devaney', 'Madsen')
# ('Devaney', 'Maioni')
# ('Devaney', 'Mayne')
# ('Devaney', 'McGough')
# ('Devaney', 'McGowan')
# ('Devaney', 'Mellinger')
# ('Devaney', 'Mellors')
# ('Devaney', 'Moor')
# ('Devaney', 'Najib')
# ('Devaney', 'Nakid')
# ('Devaney', 'Nasser')
# ('Devaney', 'Newell')
# ('Devaney', 'Newsom')
# ('Devaney', 'Nicola-Yarred')
# ('Devaney', 'Nilsson')
# ('Devaney', 'Niskanen')
# ('Devaney', 'Nye')
# ('Devaney', 'Nysten')
# ('Devaney', 'Ohman')
# ('Devaney', 'Osman')
# ('Devaney', 'Parrish')
# ('Devaney', 'Pears')
# ('Devaney', 'Penasco y Castellana')
# ('Devaney', 'Perreault')
# ('Devaney', 'Persson')
# ('Devaney', 'Peuchen')
# ('Devaney', 'Phillips')
# ('Devaney', 'Pickard')
# ('Devaney', 'Pinsky')
# ('Devaney', 'Potter')
# ('Devaney', 'Quick')
# ('Devaney', 'Reynaldo')
# ('Devaney', 'Richards')
# ('Devaney', 'Ridsdale')
# ('Devaney', 'Robert')
# ('Devaney', 'Romaine')
# ('Devaney', 'Rothes')
# ('Devaney', 'Rothschild')
# ('Devaney', 'Rugg')
# ('Devaney', 'Ryerson')
# ('Devaney', 'Sagesser')
# ('Devaney', 'Salkjelsvik')
# ('Devaney', 'Sandstrom')
# ('Devaney', 'Serepeca')
# ('Devaney', 'Seward')
# ('Devaney', 'Sheerlinck')
# ('Devaney', 'Shelley')
# ('Devaney', 'Shutes')
# ('Devaney', 'Silven')
# ('Devaney', 'Silverthorne')
# ('Devaney', 'Simonius-Blumer')
# ('Devaney', 'Sinkkonen')
# ('Devaney', 'Sjoblom')
# ('Devaney', 'Slayter')
# ('Devaney', 'Sloper')
# ('Devaney', 'Spedden')
# ('Devaney', 'Stahelin-Maeglin')
# ('Devaney', 'Stephenson')
# ('Devaney', 'Stone')
# ('Devaney', 'Stranden')
# ('Devaney', 'Sunderland')
# ('Devaney', 'Sundman')
# ('Devaney', 'Swift')
# ('Devaney', 'Taylor')
# ('Devaney', 'Thayer')
# ('Devaney', 'Thomas')
# ('Devaney', 'Toomey')
# ('Devaney', 'Tornquist')
# ('Devaney', 'Touma')
# ('Devaney', 'Trout')
# ('Devaney', 'Troutt')
# ('Devaney', 'Turja')
# ('Devaney', 'Turkula')
# ('Devaney', 'Ward')
# ('Devaney', 'Warren')
# ('Devaney', 'Watt')
# ('Devaney', 'Webber')
# ('Devaney', 'Weisz')
# ('Devaney', 'Wells')
# ('Devaney', 'West')
# ('Devaney', 'Wick')
# ('Devaney', 'Wilhelms')
# ('Devaney', 'Young')
# ('Devaney', 'de Messemaeker')
# ('Devaney', 'de Mulder')
# ('Harper', 'Hassab')
# ('Harper', 'Hays')
# ('Harper', 'Hedman')
# ('Harper', 'Heikkinen')
# ('Harper', 'Herman')
# ('Harper', 'Hewlett')
# ('Harper', 'Hippach')
# ('Harper', 'Hirvonen')
# ('Harper', 'Hogeboom')
# ('Harper', 'Homer')
# ('Harper', 'Honkanen')
# ('Harper', 'Hosono')
# ('Harper', 'Hoyt')
# ('Harper', 'Icard')
# ('Harper', 'Ilett')
# ('Harper', 'Jalsevac')
# ('Harper', 'Jansson')
# ('Harper', 'Jerwan')
# ('Harper', 'Johnson')
# ('Harper', 'Jonsson')
# ('Harper', 'Karun')
# ('Harper', 'Kimball')
# ('Harper', 'Kink-Heilmann')
# ('Harper', 'Landergren')
# ('Harper', 'Lang')
# ('Harper', 'Laroche')
# ('Harper', 'LeRoy')
# ('Harper', 'Leader')
# ('Harper', 'Leeni')
# ('Harper', 'Lehmann')
# ('Harper', 'Lemore')
# ('Harper', 'Lesurer')
# ('Harper', 'Lindqvist')
# ('Harper', 'Lines')
# ('Harper', 'Longley')
# ('Harper', 'Louch')
# ('Harper', 'Lulic')
# ('Harper', 'Lurette')
# ('Harper', 'Madill')
# ('Harper', 'Madsen')
# ('Harper', 'Maioni')
# ('Harper', 'Mayne')
# ('Harper', 'McGough')
# ('Harper', 'McGowan')
# ('Harper', 'Mellinger')
# ('Harper', 'Mellors')
# ('Harper', 'Moor')
# ('Harper', 'Najib')
# ('Harper', 'Nakid')
# ('Harper', 'Nasser')
# ('Harper', 'Newell')
# ('Harper', 'Newsom')
# ('Harper', 'Nicola-Yarred')
# ('Harper', 'Nilsson')
# ('Harper', 'Niskanen')
# ('Harper', 'Nye')
# ('Harper', 'Nysten')
# ('Harper', 'Ohman')
# ('Harper', 'Osman')
# ('Harper', 'Parrish')
# ('Harper', 'Pears')
# ('Harper', 'Penasco y Castellana')
# ('Harper', 'Perreault')
# ('Harper', 'Persson')
# ('Harper', 'Peuchen')
# ('Harper', 'Phillips')
# ('Harper', 'Pickard')
# ('Harper', 'Pinsky')
# ('Harper', 'Potter')
# ('Harper', 'Quick')
# ('Harper', 'Reynaldo')
# ('Harper', 'Richards')
# ('Harper', 'Ridsdale')
# ('Harper', 'Robert')
# ('Harper', 'Romaine')
# ('Harper', 'Rothes')
# ('Harper', 'Rothschild')
# ('Harper', 'Rugg')
# ('Harper', 'Ryerson')
# ('Harper', 'Sagesser')
# ('Harper', 'Salkjelsvik')
# ('Harper', 'Sandstrom')
# ('Harper', 'Serepeca')
# ('Harper', 'Seward')
# ('Harper', 'Sheerlinck')
# ('Harper', 'Shelley')
# ('Harper', 'Shutes')
# ('Harper', 'Silven')
# ('Harper', 'Silverthorne')
# ('Harper', 'Simonius-Blumer')
# ('Harper', 'Sinkkonen')
# ('Harper', 'Sjoblom')
# ('Harper', 'Slayter')
# ('Harper', 'Sloper')
# ('Harper', 'Spedden')
# ('Harper', 'Stahelin-Maeglin')
# ('Harper', 'Stephenson')
# ('Harper', 'Stone')
# ('Harper', 'Stranden')
# ('Harper', 'Sunderland')
# ('Harper', 'Sundman')
# ('Harper', 'Swift')
# ('Harper', 'Taylor')
# ('Harper', 'Thayer')
# ('Harper', 'Thomas')
# ('Harper', 'Toomey')
# ('Harper', 'Tornquist')
# ('Harper', 'Touma')
# ('Harper', 'Trout')
# ('Harper', 'Troutt')
# ('Harper', 'Turja')
# ('Harper', 'Turkula')
# ('Harper', 'Ward')
# ('Harper', 'Warren')
# ('Harper', 'Watt')
# ('Harper', 'Webber')
# ('Harper', 'Weisz')
# ('Harper', 'Wells')
# ('Harper', 'West')
# ('Harper', 'Wick')
# ('Harper', 'Wilhelms')
# ('Harper', 'Young')
# ('Harper', 'de Messemaeker')
# ('Harper', 'de Mulder')
# ('Faunthorpe', 'Flynn')
# ('Faunthorpe', 'Francatelli')
# ('Faunthorpe', 'Frauenthal')
# ('Faunthorpe', 'Frolicher')
# ('Faunthorpe', 'Frolicher-Stehli')
# ('Faunthorpe', 'Futrelle')
# ('Faunthorpe', 'Garside')
# ('Faunthorpe', 'Gilnagh')
# ('Faunthorpe', 'Goldenberg')
# ('Faunthorpe', 'Goldsmith')
# ('Faunthorpe', 'Graham')
# ('Faunthorpe', 'Greenfield')
# ('Faunthorpe', 'Hakkarainen')
# ('Faunthorpe', 'Hamalainen')
# ('Faunthorpe', 'Harder')
# ('Faunthorpe', 'Harper')
# ('Faunthorpe', 'Hassab')
# ('Faunthorpe', 'Hays')
# ('Faunthorpe', 'Hedman')
# ('Faunthorpe', 'Heikkinen')
# ('Faunthorpe', 'Herman')
# ('Faunthorpe', 'Hewlett')
# ('Faunthorpe', 'Hippach')
# ('Faunthorpe', 'Hirvonen')
# ('Faunthorpe', 'Hogeboom')
# ('Faunthorpe', 'Homer')
# ('Faunthorpe', 'Honkanen')
# ('Faunthorpe', 'Hosono')
# ('Faunthorpe', 'Hoyt')
# ('Faunthorpe', 'Icard')
# ('Faunthorpe', 'Ilett')
# ('Faunthorpe', 'Jalsevac')
# ('Faunthorpe', 'Jansson')
# ('Faunthorpe', 'Jerwan')
# ('Faunthorpe', 'Johnson')
# ('Faunthorpe', 'Jonsson')
# ('Faunthorpe', 'Karun')
# ('Faunthorpe', 'Kimball')
# ('Faunthorpe', 'Kink-Heilmann')
# ('Faunthorpe', 'Landergren')
# ('Faunthorpe', 'Lang')
# ('Faunthorpe', 'Laroche')
# ('Faunthorpe', 'LeRoy')
# ('Faunthorpe', 'Leader')
# ('Faunthorpe', 'Leeni')
# ('Faunthorpe', 'Lehmann')
# ('Faunthorpe', 'Lemore')
# ('Faunthorpe', 'Lesurer')
# ('Faunthorpe', 'Lindqvist')
# ('Faunthorpe', 'Lines')
# ('Faunthorpe', 'Longley')
# ('Faunthorpe', 'Louch')
# ('Faunthorpe', 'Lulic')
# ('Faunthorpe', 'Lurette')
# ('Faunthorpe', 'Madill')
# ('Faunthorpe', 'Madsen')
# ('Faunthorpe', 'Maioni')
# ('Faunthorpe', 'Mayne')
# ('Faunthorpe', 'McGough')
# ('Faunthorpe', 'McGowan')
# ('Faunthorpe', 'Mellinger')
# ('Faunthorpe', 'Mellors')
# ('Faunthorpe', 'Moor')
# ('Faunthorpe', 'Najib')
# ('Faunthorpe', 'Nakid')
# ('Faunthorpe', 'Nasser')
# ('Faunthorpe', 'Newell')
# ('Faunthorpe', 'Newsom')
# ('Faunthorpe', 'Nicola-Yarred')
# ('Faunthorpe', 'Nilsson')
# ('Faunthorpe', 'Niskanen')
# ('Faunthorpe', 'Nye')
# ('Faunthorpe', 'Nysten')
# ('Faunthorpe', 'Ohman')
# ('Faunthorpe', 'Osman')
# ('Faunthorpe', 'Parrish')
# ('Faunthorpe', 'Pears')
# ('Faunthorpe', 'Penasco y Castellana')
# ('Faunthorpe', 'Perreault')
# ('Faunthorpe', 'Persson')
# ('Faunthorpe', 'Peuchen')
# ('Faunthorpe', 'Phillips')
# ('Faunthorpe', 'Pickard')
# ('Faunthorpe', 'Pinsky')
# ('Faunthorpe', 'Potter')
# ('Faunthorpe', 'Quick')
# ('Faunthorpe', 'Reynaldo')
# ('Faunthorpe', 'Richards')
# ('Faunthorpe', 'Ridsdale')
# ('Faunthorpe', 'Robert')
# ('Faunthorpe', 'Romaine')
# ('Faunthorpe', 'Rothes')
# ('Faunthorpe', 'Rothschild')
# ('Faunthorpe', 'Rugg')
# ('Faunthorpe', 'Ryerson')
# ('Faunthorpe', 'Sagesser')
# ('Faunthorpe', 'Salkjelsvik')
# ('Faunthorpe', 'Sandstrom')
# ('Faunthorpe', 'Serepeca')
# ('Faunthorpe', 'Seward')
# ('Faunthorpe', 'Sheerlinck')
# ('Faunthorpe', 'Shelley')
# ('Faunthorpe', 'Shutes')
# ('Faunthorpe', 'Silven')
# ('Faunthorpe', 'Silverthorne')
# ('Faunthorpe', 'Simonius-Blumer')
# ('Faunthorpe', 'Sinkkonen')
# ('Faunthorpe', 'Sjoblom')
# ('Faunthorpe', 'Slayter')
# ('Faunthorpe', 'Sloper')
# ('Faunthorpe', 'Spedden')
# ('Faunthorpe', 'Stahelin-Maeglin')
# ('Faunthorpe', 'Stephenson')
# ('Faunthorpe', 'Stone')
# ('Faunthorpe', 'Stranden')
# ('Faunthorpe', 'Sunderland')
# ('Faunthorpe', 'Sundman')
# ('Faunthorpe', 'Swift')
# ('Faunthorpe', 'Taylor')
# ('Faunthorpe', 'Thayer')
# ('Faunthorpe', 'Thomas')
# ('Faunthorpe', 'Toomey')
# ('Faunthorpe', 'Tornquist')
# ('Faunthorpe', 'Touma')
# ('Faunthorpe', 'Trout')
# ('Faunthorpe', 'Troutt')
# ('Faunthorpe', 'Turja')
# ('Faunthorpe', 'Turkula')
# ('Faunthorpe', 'Ward')
# ('Faunthorpe', 'Warren')
# ('Faunthorpe', 'Watt')
# ('Faunthorpe', 'Webber')
# ('Faunthorpe', 'Weisz')
# ('Faunthorpe', 'Wells')
# ('Faunthorpe', 'West')
# ('Faunthorpe', 'Wick')
# ('Faunthorpe', 'Wilhelms')
# ('Faunthorpe', 'Young')
# ('Faunthorpe', 'de Messemaeker')
# ('Faunthorpe', 'de Mulder')
# ('Rugg', 'Ryerson')
# ('Rugg', 'Sagesser')
# ('Rugg', 'Salkjelsvik')
# ('Rugg', 'Sandstrom')
# ('Rugg', 'Serepeca')
# ('Rugg', 'Seward')
# ('Rugg', 'Sheerlinck')
# ('Rugg', 'Shelley')
# ('Rugg', 'Shutes')
# ('Rugg', 'Silven')
# ('Rugg', 'Silverthorne')
# ('Rugg', 'Simonius-Blumer')
# ('Rugg', 'Sinkkonen')
# ('Rugg', 'Sjoblom')
# ('Rugg', 'Slayter')
# ('Rugg', 'Sloper')
# ('Rugg', 'Spedden')
# ('Rugg', 'Stahelin-Maeglin')
# ('Rugg', 'Stephenson')
# ('Rugg', 'Stone')
# ...
# ('Swift', 'Thayer')
# ('Swift', 'Thomas')
# ('Swift', 'Toomey')
# ('Swift', 'Tornquist')
# ('Swift', 'Touma')
# ('Swift', 'Trout')
# ('Swift', 'Troutt')
# ('Swift', 'Turja')
# ('Swift', 'Turkula')
# ('Swift', 'Ward')
# ('Swift', 'Warren')
# ('Swift', 'Watt')
# ('Swift', 'Webber')
# ('Swift', 'Weisz')
# ('Swift', 'Wells')
# ('Swift', 'West')
# ('Swift', 'Wick')
# ('Swift', 'Wilhelms')
# ('Swift', 'Young')
# ('Swift', 'de Messemaeker')
# ('Swift', 'de Mulder')
# ('Bystrom', 'Calderhead')
# ('Bystrom', 'Caldwell')
# ('Bystrom', 'Cameron')
# ('Bystrom', 'Cardeza')
# ('Bystrom', 'Carr')
# ('Bystrom', 'Chambers')
# ('Bystrom', 'Cherry')
# ('Bystrom', 'Chip')
# ('Bystrom', 'Christy')
# ('Bystrom', 'Clarke')
# ('Bystrom', 'Cleaver')
# ('Bystrom', 'Cohen')
# ('Bystrom', 'Collyer')
# ('Bystrom', 'Compton')
# ('Bystrom', 'Connolly')
# ('Bystrom', 'Coutts')
# ('Bystrom', 'Crosby')
# ('Bystrom', 'Cumings')
# ('Bystrom', 'Dahl')
# ('Bystrom', 'Daly')
# ('Bystrom', 'Daniel')
# ('Bystrom', 'Davis')
# ('Bystrom', 'Devaney')
# ('Bystrom', 'Dick')
# ('Bystrom', 'Dodge')
# ('Bystrom', 'Doling')
# ('Bystrom', 'Dorking')
# ('Bystrom', 'Dowdell')
# ('Bystrom', 'Drew')
# ('Bystrom', 'Duff Gordon')
# ('Bystrom', 'Duran y More')
# ('Bystrom', 'Emanuel')
# ('Bystrom', 'Endres')
# ('Bystrom', 'Eustis')
# ('Bystrom', 'Faunthorpe')
# ('Bystrom', 'Flynn')
# ('Bystrom', 'Francatelli')
# ('Bystrom', 'Frauenthal')
# ('Bystrom', 'Frolicher')
# ('Bystrom', 'Frolicher-Stehli')
# ('Bystrom', 'Futrelle')
# ('Bystrom', 'Garside')
# ('Bystrom', 'Gilnagh')
# ('Bystrom', 'Goldenberg')
# ('Bystrom', 'Goldsmith')
# ('Bystrom', 'Graham')
# ('Bystrom', 'Greenfield')
# ('Bystrom', 'Hakkarainen')
# ('Bystrom', 'Hamalainen')
# ('Bystrom', 'Harder')
# ('Bystrom', 'Harper')
# ('Bystrom', 'Hassab')
# ('Bystrom', 'Hays')
# ('Bystrom', 'Hedman')
# ('Bystrom', 'Heikkinen')
# ('Bystrom', 'Herman')
# ('Bystrom', 'Hewlett')
# ('Bystrom', 'Hippach')
# ('Bystrom', 'Hirvonen')
# ('Bystrom', 'Hogeboom')
# ('Bystrom', 'Homer')
# ('Bystrom', 'Honkanen')
# ('Bystrom', 'Hosono')
# ('Bystrom', 'Hoyt')
# ('Bystrom', 'Icard')
# ('Bystrom', 'Ilett')
# ('Bystrom', 'Jalsevac')
# ('Bystrom', 'Jansson')
# ('Bystrom', 'Jerwan')
# ('Bystrom', 'Johnson')
# ('Bystrom', 'Jonsson')
# ('Bystrom', 'Karun')
# ('Bystrom', 'Kimball')
# ('Bystrom', 'Kink-Heilmann')
# ('Bystrom', 'Landergren')
# ('Bystrom', 'Lang')
# ('Bystrom', 'Laroche')
# ('Bystrom', 'LeRoy')
# ('Bystrom', 'Leader')
# ('Bystrom', 'Leeni')
# ('Bystrom', 'Lehmann')
# ('Bystrom', 'Lemore')
# ('Bystrom', 'Lesurer')
# ('Bystrom', 'Lindqvist')
# ('Bystrom', 'Lines')
# ('Bystrom', 'Longley')
# ('Bystrom', 'Louch')
# ('Bystrom', 'Lulic')
# ('Bystrom', 'Lurette')
# ('Bystrom', 'Madill')
# ('Bystrom', 'Madsen')
# ('Bystrom', 'Maioni')
# ('Bystrom', 'Mayne')
# ('Bystrom', 'McGough')
# ('Bystrom', 'McGowan')
# ('Bystrom', 'Mellinger')
# ('Bystrom', 'Mellors')
# ('Bystrom', 'Moor')
# ('Bystrom', 'Najib')
# ('Bystrom', 'Nakid')
# ('Bystrom', 'Nasser')
# ('Bystrom', 'Newell')
# ('Bystrom', 'Newsom')
# ('Bystrom', 'Nicola-Yarred')
# ('Bystrom', 'Nilsson')
# ('Bystrom', 'Niskanen')
# ('Bystrom', 'Nye')
# ('Bystrom', 'Nysten')
# ('Bystrom', 'Ohman')
# ('Bystrom', 'Osman')
# ('Bystrom', 'Parrish')
# ('Bystrom', 'Pears')
# ('Bystrom', 'Penasco y Castellana')
# ('Bystrom', 'Perreault')
# ('Bystrom', 'Persson')
# ('Bystrom', 'Peuchen')
# ('Bystrom', 'Phillips')
# ('Bystrom', 'Pickard')
# ('Bystrom', 'Pinsky')
# ('Bystrom', 'Potter')
# ('Bystrom', 'Quick')
# ('Bystrom', 'Reynaldo')
# ('Bystrom', 'Richards')
# ('Bystrom', 'Ridsdale')
# ('Bystrom', 'Robert')
# ('Bystrom', 'Romaine')
# ('Bystrom', 'Rothes')
# ('Bystrom', 'Rothschild')
# ('Bystrom', 'Rugg')
# ('Bystrom', 'Ryerson')
# ('Bystrom', 'Sagesser')
# ('Bystrom', 'Salkjelsvik')
# ('Bystrom', 'Sandstrom')
# ('Bystrom', 'Serepeca')
# ('Bystrom', 'Seward')
# ('Bystrom', 'Sheerlinck')
# ('Bystrom', 'Shelley')
# ('Bystrom', 'Shutes')
# ('Bystrom', 'Silven')
# ('Bystrom', 'Silverthorne')
# ('Bystrom', 'Simonius-Blumer')
# ('Bystrom', 'Sinkkonen')
# ('Bystrom', 'Sjoblom')
# ('Bystrom', 'Slayter')
# ('Bystrom', 'Sloper')
# ('Bystrom', 'Spedden')
# ('Bystrom', 'Stahelin-Maeglin')
# ('Bystrom', 'Stephenson')
# ('Bystrom', 'Stone')
# ('Bystrom', 'Stranden')
# ('Bystrom', 'Sunderland')
# ('Bystrom', 'Sundman')
# ('Bystrom', 'Swift')
# ('Bystrom', 'Taylor')
# ('Bystrom', 'Thayer')
# ('Bystrom', 'Thomas')
# ('Bystrom', 'Toomey')
# ('Bystrom', 'Tornquist')
# ('Bystrom', 'Touma')
# ('Bystrom', 'Trout')
# ('Bystrom', 'Troutt')
# ('Bystrom', 'Turja')
# ('Bystrom', 'Turkula')
# ('Bystrom', 'Ward')
# ('Bystrom', 'Warren')
# ('Bystrom', 'Watt')
# ('Bystrom', 'Webber')
# ('Bystrom', 'Weisz')
# ('Bystrom', 'Wells')
# ('Bystrom', 'West')
# ('Bystrom', 'Wick')
# ('Bystrom', 'Wilhelms')
# ('Bystrom', 'Young')
# ('Bystrom', 'de Messemaeker')
# ('Bystrom', 'de Mulder')
# ('Duran y More', 'Emanuel')
# ('Duran y More', 'Endres')
# ('Duran y More', 'Eustis')
# ('Duran y More', 'Faunthorpe')
# ('Duran y More', 'Flynn')
# ('Duran y More', 'Francatelli')
# ('Duran y More', 'Frauenthal')
# ('Duran y More', 'Frolicher')
# ('Duran y More', 'Frolicher-Stehli')
# ('Duran y More', 'Futrelle')
# ('Duran y More', 'Garside')
# ('Duran y More', 'Gilnagh')
# ('Duran y More', 'Goldenberg')
# ('Duran y More', 'Goldsmith')
# ('Duran y More', 'Graham')
# ('Duran y More', 'Greenfield')
# ('Duran y More', 'Hakkarainen')
# ('Duran y More', 'Hamalainen')
# ('Duran y More', 'Harder')
# ('Duran y More', 'Harper')
# ('Duran y More', 'Hassab')
# ('Duran y More', 'Hays')
# ('Duran y More', 'Hedman')
# ('Duran y More', 'Heikkinen')
# ('Duran y More', 'Herman')
# ('Duran y More', 'Hewlett')
# ('Duran y More', 'Hippach')
# ('Duran y More', 'Hirvonen')
# ('Duran y More', 'Hogeboom')
# ('Duran y More', 'Homer')
# ('Duran y More', 'Honkanen')
# ('Duran y More', 'Hosono')
# ('Duran y More', 'Hoyt')
# ('Duran y More', 'Icard')
# ('Duran y More', 'Ilett')
# ('Duran y More', 'Jalsevac')
# ('Duran y More', 'Jansson')
# ('Duran y More', 'Jerwan')
# ('Duran y More', 'Johnson')
# ('Duran y More', 'Jonsson')
# ('Duran y More', 'Karun')
# ('Duran y More', 'Kimball')
# ('Duran y More', 'Kink-Heilmann')
# ('Duran y More', 'Landergren')
# ('Duran y More', 'Lang')
# ('Duran y More', 'Laroche')
# ('Duran y More', 'LeRoy')
# ('Duran y More', 'Leader')
# ('Duran y More', 'Leeni')
# ('Duran y More', 'Lehmann')
# ('Duran y More', 'Lemore')
# ('Duran y More', 'Lesurer')
# ('Duran y More', 'Lindqvist')
# ('Duran y More', 'Lines')
# ('Duran y More', 'Longley')
# ('Duran y More', 'Louch')
# ('Duran y More', 'Lulic')
# ('Duran y More', 'Lurette')
# ('Duran y More', 'Madill')
# ('Duran y More', 'Madsen')
# ('Duran y More', 'Maioni')
# ('Duran y More', 'Mayne')
# ('Duran y More', 'McGough')
# ('Duran y More', 'McGowan')
# ('Duran y More', 'Mellinger')
# ('Duran y More', 'Mellors')
# ('Duran y More', 'Moor')
# ('Duran y More', 'Najib')
# ('Duran y More', 'Nakid')
# ('Duran y More', 'Nasser')
# ('Duran y More', 'Newell')
# ('Duran y More', 'Newsom')
# ('Duran y More', 'Nicola-Yarred')
# ('Duran y More', 'Nilsson')
# ('Duran y More', 'Niskanen')
# ('Duran y More', 'Nye')
# ('Duran y More', 'Nysten')
# ('Duran y More', 'Ohman')
# ('Duran y More', 'Osman')
# ('Duran y More', 'Parrish')
# ('Duran y More', 'Pears')
# ('Duran y More', 'Penasco y Castellana')
# ('Duran y More', 'Perreault')
# ('Duran y More', 'Persson')
# ('Duran y More', 'Peuchen')
# ('Duran y More', 'Phillips')
# ('Duran y More', 'Pickard')
# ('Duran y More', 'Pinsky')
# ('Duran y More', 'Potter')
# ('Duran y More', 'Quick')
# ('Duran y More', 'Reynaldo')
# ('Duran y More', 'Richards')
# ('Duran y More', 'Ridsdale')
# ('Duran y More', 'Robert')
# ('Duran y More', 'Romaine')
# ('Duran y More', 'Rothes')
# ('Duran y More', 'Rothschild')
# ('Duran y More', 'Rugg')
# ('Duran y More', 'Ryerson')
# ('Duran y More', 'Sagesser')
# ('Duran y More', 'Salkjelsvik')
# ('Duran y More', 'Sandstrom')
# ('Duran y More', 'Serepeca')
# ('Duran y More', 'Seward')
# ('Duran y More', 'Sheerlinck')
# ('Duran y More', 'Shelley')
# ('Duran y More', 'Shutes')
# ('Duran y More', 'Silven')
# ('Duran y More', 'Silverthorne')
# ('Duran y More', 'Simonius-Blumer')
# ('Duran y More', 'Sinkkonen')
# ('Duran y More', 'Sjoblom')
# ('Duran y More', 'Slayter')
# ('Duran y More', 'Sloper')
# ('Duran y More', 'Spedden')
# ('Duran y More', 'Stahelin-Maeglin')
# ('Duran y More', 'Stephenson')
# ('Duran y More', 'Stone')
# ('Duran y More', 'Stranden')
# ('Duran y More', 'Sunderland')
# ('Duran y More', 'Sundman')
# ('Duran y More', 'Swift')
# ('Duran y More', 'Taylor')
# ('Duran y More', 'Thayer')
# ('Duran y More', 'Thomas')
# ('Duran y More', 'Toomey')
# ('Duran y More', 'Tornquist')
# ('Duran y More', 'Touma')
# ('Duran y More', 'Trout')
# ('Duran y More', 'Troutt')
# ('Duran y More', 'Turja')
# ('Duran y More', 'Turkula')
# ('Duran y More', 'Ward')
# ('Duran y More', 'Warren')
# ('Duran y More', 'Watt')
# ('Duran y More', 'Webber')
# ('Duran y More', 'Weisz')
# ('Duran y More', 'Wells')
# ('Duran y More', 'West')
# ('Duran y More', 'Wick')
# ('Duran y More', 'Wilhelms')
# ('Duran y More', 'Young')
# ('Duran y More', 'de Messemaeker')
# ('Duran y More', 'de Mulder')
# ('Najib', 'Nakid')
# ('Najib', 'Nasser')
# ('Najib', 'Newell')
# ('Najib', 'Newsom')
# ('Najib', 'Nicola-Yarred')
# ('Najib', 'Nilsson')
# ('Najib', 'Niskanen')
# ('Najib', 'Nye')
# ('Najib', 'Nysten')
# ('Najib', 'Ohman')
# ('Najib', 'Osman')
# ('Najib', 'Parrish')
# ('Najib', 'Pears')
# ('Najib', 'Penasco y Castellana')
# ('Najib', 'Perreault')
# ('Najib', 'Persson')
# ('Najib', 'Peuchen')
# ('Najib', 'Phillips')
# ('Najib', 'Pickard')
# ('Najib', 'Pinsky')
# ('Najib', 'Potter')
# ('Najib', 'Quick')
# ('Najib', 'Reynaldo')
# ('Najib', 'Richards')
# ('Najib', 'Ridsdale')
# ('Najib', 'Robert')
# ('Najib', 'Romaine')
# ('Najib', 'Rothes')
# ('Najib', 'Rothschild')
# ('Najib', 'Rugg')
# ('Najib', 'Ryerson')
# ('Najib', 'Sagesser')
# ('Najib', 'Salkjelsvik')
# ('Najib', 'Sandstrom')
# ('Najib', 'Serepeca')
# ('Najib', 'Seward')
# ('Najib', 'Sheerlinck')
# ('Najib', 'Shelley')
# ('Najib', 'Shutes')
# ('Najib', 'Silven')
# ('Najib', 'Silverthorne')
# ('Najib', 'Simonius-Blumer')
# ('Najib', 'Sinkkonen')
# ('Najib', 'Sjoblom')
# ('Najib', 'Slayter')
# ('Najib', 'Sloper')
# ('Najib', 'Spedden')
# ('Najib', 'Stahelin-Maeglin')
# ('Najib', 'Stephenson')
# ('Najib', 'Stone')
# ('Najib', 'Stranden')
# ('Najib', 'Sunderland')
# ('Najib', 'Sundman')
# ('Najib', 'Swift')
# ('Najib', 'Taylor')
# ('Najib', 'Thayer')
# ('Najib', 'Thomas')
# ('Najib', 'Toomey')
# ('Najib', 'Tornquist')
# ('Najib', 'Touma')
# ('Najib', 'Trout')
# ('Najib', 'Troutt')
# ('Najib', 'Turja')
# ('Najib', 'Turkula')
# ('Najib', 'Ward')
# ('Najib', 'Warren')
# ('Najib', 'Watt')
# ('Najib', 'Webber')
# ('Najib', 'Weisz')
# ('Najib', 'Wells')
# ('Najib', 'West')
# ('Najib', 'Wick')
# ('Najib', 'Wilhelms')
# ('Najib', 'Young')
# ('Najib', 'de Messemaeker')
# ('Najib', 'de Mulder')
# ('Potter', 'Quick')
# ('Potter', 'Reynaldo')
# ('Potter', 'Richards')
# ('Potter', 'Ridsdale')
# ('Potter', 'Robert')
# ('Potter', 'Romaine')
# ('Potter', 'Rothes')
# ('Potter', 'Rothschild')
# ('Potter', 'Rugg')
# ('Potter', 'Ryerson')
# ('Potter', 'Sagesser')
# ('Potter', 'Salkjelsvik')
# ('Potter', 'Sandstrom')
# ('Potter', 'Serepeca')
# ('Potter', 'Seward')
# ('Potter', 'Sheerlinck')
# ('Potter', 'Shelley')
# ('Potter', 'Shutes')
# ('Potter', 'Silven')
# ('Potter', 'Silverthorne')
# ('Potter', 'Simonius-Blumer')
# ('Potter', 'Sinkkonen')
# ('Potter', 'Sjoblom')
# ('Potter', 'Slayter')
# ('Potter', 'Sloper')
# ('Potter', 'Spedden')
# ('Potter', 'Stahelin-Maeglin')
# ('Potter', 'Stephenson')
# ('Potter', 'Stone')
# ('Potter', 'Stranden')
# ('Potter', 'Sunderland')
# ('Potter', 'Sundman')
# ('Potter', 'Swift')
# ('Potter', 'Taylor')
# ('Potter', 'Thayer')
# ('Potter', 'Thomas')
# ('Potter', 'Toomey')
# ('Potter', 'Tornquist')
# ('Potter', 'Touma')
# ('Potter', 'Trout')
# ('Potter', 'Troutt')
# ('Potter', 'Turja')
# ('Potter', 'Turkula')
# ('Potter', 'Ward')
# ('Potter', 'Warren')
# ('Potter', 'Watt')
# ('Potter', 'Webber')
# ('Potter', 'Weisz')
# ('Potter', 'Wells')
# ('Potter', 'West')
# ('Potter', 'Wick')
# ('Potter', 'Wilhelms')
# ('Potter', 'Young')
# ('Potter', 'de Messemaeker')
# ('Potter', 'de Mulder')
# ('Shelley', 'Shutes')
# ('Shelley', 'Silven')
# ('Shelley', 'Silverthorne')
# ('Shelley', 'Simonius-Blumer')
# ('Shelley', 'Sinkkonen')
# ('Shelley', 'Sjoblom')
# ('Shelley', 'Slayter')
# ('Shelley', 'Sloper')
# ('Shelley', 'Spedden')
# ('Shelley', 'Stahelin-Maeglin')
# ('Shelley', 'Stephenson')
# ('Shelley', 'Stone')
# ('Shelley', 'Stranden')
# ('Shelley', 'Sunderland')
# ('Shelley', 'Sundman')
# ('Shelley', 'Swift')
# ('Shelley', 'Taylor')
# ('Shelley', 'Thayer')
# ('Shelley', 'Thomas')
# ('Shelley', 'Toomey')
# ('Shelley', 'Tornquist')
# ('Shelley', 'Touma')
# ('Shelley', 'Trout')
# ('Shelley', 'Troutt')
# ('Shelley', 'Turja')
# ('Shelley', 'Turkula')
# ('Shelley', 'Ward')
# ('Shelley', 'Warren')
# ('Shelley', 'Watt')
# ('Shelley', 'Webber')
# ('Shelley', 'Weisz')
# ('Shelley', 'Wells')
# ('Shelley', 'West')
# ('Shelley', 'Wick')
# ('Shelley', 'Wilhelms')
# ('Shelley', 'Young')
# ('Shelley', 'de Messemaeker')
# ('Shelley', 'de Mulder')
# ('Behr', 'Bidois')
# ('Behr', 'Bing')
# ('Behr', 'Bishop')
# ('Behr', 'Bissette')
# ('Behr', 'Bjornstrom-Steffansson')
# ('Behr', 'Blank')
# ('Behr', 'Bonnell')
# ('Behr', 'Bowerman')
# ('Behr', 'Brown')
# ('Behr', 'Burns')
# ('Behr', 'Buss')
# ('Behr', 'Bystrom')
# ('Behr', 'Calderhead')
# ('Behr', 'Caldwell')
# ('Behr', 'Cameron')
# ('Behr', 'Cardeza')
# ('Behr', 'Carr')
# ('Behr', 'Chambers')
# ('Behr', 'Cherry')
# ('Behr', 'Chip')
# ('Behr', 'Christy')
# ('Behr', 'Clarke')
# ('Behr', 'Cleaver')
# ('Behr', 'Cohen')
# ('Behr', 'Collyer')
# ('Behr', 'Compton')
# ('Behr', 'Connolly')
# ('Behr', 'Coutts')
# ('Behr', 'Crosby')
# ('Behr', 'Cumings')
# ('Behr', 'Dahl')
# ('Behr', 'Daly')
# ('Behr', 'Daniel')
# ('Behr', 'Davis')
# ('Behr', 'Devaney')
# ('Behr', 'Dick')
# ('Behr', 'Dodge')
# ('Behr', 'Doling')
# ('Behr', 'Dorking')
# ('Behr', 'Dowdell')
# ('Behr', 'Drew')
# ('Behr', 'Duff Gordon')
# ('Behr', 'Duran y More')
# ('Behr', 'Emanuel')
# ('Behr', 'Endres')
# ('Behr', 'Eustis')
# ('Behr', 'Faunthorpe')
# ('Behr', 'Flynn')
# ('Behr', 'Francatelli')
# ('Behr', 'Frauenthal')
# ('Behr', 'Frolicher')
# ('Behr', 'Frolicher-Stehli')
# ('Behr', 'Futrelle')
# ('Behr', 'Garside')
# ('Behr', 'Gilnagh')
# ('Behr', 'Goldenberg')
# ('Behr', 'Goldsmith')
# ('Behr', 'Graham')
# ('Behr', 'Greenfield')
# ('Behr', 'Hakkarainen')
# ('Behr', 'Hamalainen')
# ('Behr', 'Harder')
# ('Behr', 'Harper')
# ('Behr', 'Hassab')
# ('Behr', 'Hays')
# ('Behr', 'Hedman')
# ('Behr', 'Heikkinen')
# ('Behr', 'Herman')
# ('Behr', 'Hewlett')
# ('Behr', 'Hippach')
# ('Behr', 'Hirvonen')
# ('Behr', 'Hogeboom')
# ('Behr', 'Homer')
# ('Behr', 'Honkanen')
# ('Behr', 'Hosono')
# ('Behr', 'Hoyt')
# ('Behr', 'Icard')
# ('Behr', 'Ilett')
# ('Behr', 'Jalsevac')
# ('Behr', 'Jansson')
# ('Behr', 'Jerwan')
# ('Behr', 'Johnson')
# ('Behr', 'Jonsson')
# ('Behr', 'Karun')
# ('Behr', 'Kimball')
# ('Behr', 'Kink-Heilmann')
# ('Behr', 'Landergren')
# ('Behr', 'Lang')
# ('Behr', 'Laroche')
# ('Behr', 'LeRoy')
# ('Behr', 'Leader')
# ('Behr', 'Leeni')
# ('Behr', 'Lehmann')
# ('Behr', 'Lemore')
# ('Behr', 'Lesurer')
# ('Behr', 'Lindqvist')
# ('Behr', 'Lines')
# ('Behr', 'Longley')
# ('Behr', 'Louch')
# ('Behr', 'Lulic')
# ('Behr', 'Lurette')
# ('Behr', 'Madill')
# ('Behr', 'Madsen')
# ('Behr', 'Maioni')
# ('Behr', 'Mayne')
# ('Behr', 'McGough')
# ('Behr', 'McGowan')
# ('Behr', 'Mellinger')
# ('Behr', 'Mellors')
# ('Behr', 'Moor')
# ('Behr', 'Najib')
# ('Behr', 'Nakid')
# ('Behr', 'Nasser')
# ('Behr', 'Newell')
# ('Behr', 'Newsom')
# ('Behr', 'Nicola-Yarred')
# ('Behr', 'Nilsson')
# ('Behr', 'Niskanen')
# ('Behr', 'Nye')
# ('Behr', 'Nysten')
# ('Behr', 'Ohman')
# ('Behr', 'Osman')
# ('Behr', 'Parrish')
# ('Behr', 'Pears')
# ('Behr', 'Penasco y Castellana')
# ('Behr', 'Perreault')
# ('Behr', 'Persson')
# ('Behr', 'Peuchen')
# ('Behr', 'Phillips')
# ('Behr', 'Pickard')
# ('Behr', 'Pinsky')
# ('Behr', 'Potter')
# ('Behr', 'Quick')
# ('Behr', 'Reynaldo')
# ('Behr', 'Richards')
# ('Behr', 'Ridsdale')
# ('Behr', 'Robert')
# ('Behr', 'Romaine')
# ('Behr', 'Rothes')
# ('Behr', 'Rothschild')
# ('Behr', 'Rugg')
# ('Behr', 'Ryerson')
# ('Behr', 'Sagesser')
# ('Behr', 'Salkjelsvik')
# ('Behr', 'Sandstrom')
# ('Behr', 'Serepeca')
# ('Behr', 'Seward')
# ('Behr', 'Sheerlinck')
# ('Behr', 'Shelley')
# ('Behr', 'Shutes')
# ('Behr', 'Silven')
# ('Behr', 'Silverthorne')
# ('Behr', 'Simonius-Blumer')
# ('Behr', 'Sinkkonen')
# ('Behr', 'Sjoblom')
# ('Behr', 'Slayter')
# ('Behr', 'Sloper')
# ('Behr', 'Spedden')
# ('Behr', 'Stahelin-Maeglin')
# ('Behr', 'Stephenson')
# ('Behr', 'Stone')
# ('Behr', 'Stranden')
# ('Behr', 'Sunderland')
# ('Behr', 'Sundman')
# ('Behr', 'Swift')
# ('Behr', 'Taylor')
# ('Behr', 'Thayer')
# ('Behr', 'Thomas')
# ('Behr', 'Toomey')
# ('Behr', 'Tornquist')
# ('Behr', 'Touma')
# ('Behr', 'Trout')
# ('Behr', 'Troutt')
# ('Behr', 'Turja')
# ('Behr', 'Turkula')
# ('Behr', 'Ward')
# ('Behr', 'Warren')
# ('Behr', 'Watt')
# ('Behr', 'Webber')
# ('Behr', 'Weisz')
# ('Behr', 'Wells')
# ('Behr', 'West')
# ('Behr', 'Wick')
# ('Behr', 'Wilhelms')
# ('Behr', 'Young')
# ('Behr', 'de Messemaeker')
# ('Behr', 'de Mulder')
